# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import math
import pathlib
import unicodedata as ud

from enum import Enum
from functools import partial
from sys import getsizeof

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pyarrow.parquet as pq
import pyarrow as pa

from numpy import sin, cos, deg2rad, rad2deg
from numpy.linalg import inv
from pandas import CategoricalDtype
from sklearn.metrics.pairwise import haversine_distances
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from tqdm.auto import tqdm

pd.set_option("max_colwidth", 900)
pd.set_option("max_rows", 100)
plt.style.use("ggplot")

# %%
class CFG:
    H3_COL = "h3_res1"
    DATA = pathlib.Path("/content/drive/My Drive/Competition/4sq/data")
    MODELS = {
        "stsb-xlm-r-multilingual": "sentence-transformers/stsb-xlm-r-multilingual",
        "all-mpnet-base-v2": "sentence-transformers/all-mpnet-base-v2",
        "all-distilroberta-v1": "sentence-transformers/all-distilroberta-v1",
        "all-MiniLM-L6-v2": "sentence-transformers/all-MiniLM-L6-v2",
        "all-MiniLM-L12-v2": "sentence-transformers/all-MiniLM-L12-v2",
    }
    MODEL_KEY = "all-MiniLM-L6-v2"
    EMBEDDING_KEYS = ["name", "categories"]
    EMBEDDING_MODEL = MODELS[MODEL_KEY]
    RANDOM_SEED = 1234
    N_CLOSEST = 25
    N_NEGATIVES = 6
    BIDIRECTIONAL = False
    TEXT_COLS = [
        "name",
        "address",
        "city",
        "state",
        "zip",
        "country",
        "url",
        "phone",
        "categories",
    ]
    NUM_COLS = ["latitude", "longitude"]

# %%
def normalize(df, cols):
    print(f"normalize: {cols}")
    df = df.copy()
    for col in cols:
        ser = df[col]
        ser = ser.str.lower()
        ser = ser.str.replace("\s", " ", regex=True)
        ser = ser.str.replace(" +", " ", regex=True)
        ser = ser.str.replace("^ $", "", regex=True)
        df[f"{col}"] = ser

        print(f"  #blank rows in {col}: {len(df[df[col] == '']):,}")
    return df


normalize_cols = partial(normalize, cols=CFG.TEXT_COLS)

# %%
def fill_na(df, cols):
    df = df.copy()
    df[cols] = df[cols].fillna("")
    return df


fill_na_cols = partial(fill_na, cols=CFG.TEXT_COLS)

# %%
def fill_blank(df, cols):
    df = df.copy()
    for col in cols:
        df[col] = df[col].str.replace("^$", "-", regex=True)
    return df


fill_blank_cols = partial(fill_blank, cols=CFG.TEXT_COLS)

# %%
def compose(transforms):
    def transform_func(df):
        for transform in transforms:
            df = transform(df)
        return df

    return transform_func

# %%
transforms = compose([fill_na_cols, normalize_cols, fill_blank_cols])

# %%
DATA = CFG.DATA

# %%
ebkeys = "_".join(CFG.EMBEDDING_KEYS)
# !cp "{DATA}/preds_dev_{CFG.H3_COL}_{ebkeys}_{CFG.MODEL_KEY}_text_seed{CFG.RANDOM_SEED}.parquet" .
# !cp "{DATA}/preds_test_{CFG.H3_COL}_{ebkeys}_{CFG.MODEL_KEY}_text_seed{CFG.RANDOM_SEED}.parquet" .

# %%
preds_dev_df = pd.read_parquet(f"{DATA}/preds_dev_{CFG.H3_COL}_{ebkeys}_{CFG.MODEL_KEY}_text_seed{CFG.RANDOM_SEED}.parquet")
preds_test_df = pd.read_parquet(f"{DATA}/preds_test_{CFG.H3_COL}_{ebkeys}_{CFG.MODEL_KEY}_text_seed{CFG.RANDOM_SEED}.parquet")

# %%
# !cp "{DATA}/train_dev.parquet" .
# !cp "{DATA}/train_test.parquet" .

# %%
train_dev = transforms(pd.read_parquet("train_dev.parquet"))
train_test = transforms(pd.read_parquet("train_test.parquet"))
# Out:
# normalize: ['name', 'address', 'city', 'state', 'zip', 'country', 'url', 'phone', 'categories']
#   #blank rows in name: 0
#   #blank rows in address: 82,194
#   #blank rows in city: 63,135
#   #blank rows in state: 84,507
#   #blank rows in zip: 116,033
#   #blank rows in country: 0
#   #blank rows in url: 160,816
#   #blank rows in phone: 145,060
#   #blank rows in categories: 21,679
# normalize: ['name', 'address', 'city', 'state', 'zip', 'country', 'url', 'phone', 'categories']
#   #blank rows in name: 0
#   #blank rows in address: 82,110
#   #blank rows in city: 62,993
#   #blank rows in state: 84,654
#   #blank rows in zip: 116,068
#   #blank rows in country: 1
#   #blank rows in url: 160,564
#   #blank rows in phone: 144,840
#   #blank rows in categories: 21,590

# %%
train_dev
# Out:
#                        id                              name   latitude  \
# 0        E_000001272c6c5d              café stad oudenaarde  50.859975
# 4        E_00001d92066153           restaurante casa cofiño  43.338196
# 5        E_000023d8f4be44                        island spa  14.518970
# 7        E_0000764d65557e                        mcdonald's  -7.265894
# 15       E_0001031ce8d446  restoran nasi kandar daun pisang   3.131100
# ...                   ...                               ...        ...
# 1138775  E_fffde923648247                           guanaco  49.287111
# 1138779  E_fffe21a2201133                   oasi di baggero  45.771066
# 1138783  E_fffe5a71e05990                      giant gaplek  -6.347549
# 1138805  E_ffff9509490675   kelab rahman putra hills course   3.218054
# 1138807  E_ffffb80854f713                              青ガエル  35.659020
#
#           longitude                                      address  \
# 0          3.634196                                  abdijstraat
# 4         -4.326821                                            -
# 5        121.018702  5th flr, newport mall, resorts world manila
# 7        112.749382              plaza surabaya, pemuda building
# 15       101.683762                                  brickfields
# ...             ...                                          ...
# 1138775 -123.117324                                            -
# 1138779    9.239384                               via cava marna
# 1138783  106.749049                                       gaplek
# 1138805  101.558533                                            -
# 1138807  139.700780                                            -
#
#                  city                           state       zip country url  \
# 0          nederename                 oost-vlaanderen      9700      be   -
# 4            caviedes                       cantabria         -      es   -
# 5          pasay city                    metro manila         -      ph   -
# 7                   -                               -         -      id   -
# 15       kuala lumpur  federal territory of kuala lum         -      my   -
# ...               ...                             ...       ...     ...  ..
# 1138775             -                               -         -      ca   -
# 1138779        merone                           italy     22046      it   -
# 1138783             -                               -         -      id   -
# 1138805             -                               -         -      my   -
# 1138807           渋谷区                             東京都  150-0043      jp   -
#
#         phone                                    categories point_of_interest  \
# 0           -                                          bars  P_677e840bb6fc7e
# 4           -                           spanish restaurants  P_809a884d4407fb
# 5           -                                          spas  P_020de174484ec6
# 7           -                         fast food restaurants  P_be89c778befb23
# 15          -                             malay restaurants  P_1357b65801de8a
# ...       ...                                           ...               ...
# 1138775     -                                   food trucks  P_e416fda64302f1
# 1138779     -  scenic lookouts, lakes, other great outdoors  P_fedaf3809e50f1
# 1138783     -                            convenience stores  P_5cf17019780002
# 1138805     -                                  golf courses  P_1a01d5511f3f36
# 1138807     -                                             -  P_7ccbeab96cd82e
#
#                  h3_res0          h3_res1          h3_res2          h3_res3  \
# 0        8019fffffffffff  81197ffffffffff  82194ffffffffff  83194dfffffffff
# 4        8039fffffffffff  81187ffffffffff  82392ffffffffff  83392dfffffffff
# 5        8069fffffffffff  81697ffffffffff  82694ffffffffff  83694efffffffff
# 7        808dfffffffffff  818dbffffffffff  828d87fffffffff  838d80fffffffff
# 15       8065fffffffffff  81653ffffffffff  826507fffffffff  836505fffffffff
# ...                  ...              ...              ...              ...
# 1138775  8029fffffffffff  8128fffffffffff  8228dffffffffff  8328defffffffff
# 1138779  801ffffffffffff  811fbffffffffff  821f9ffffffffff  831f99fffffffff
# 1138783  808dfffffffffff  818c3ffffffffff  828c17fffffffff  838c10fffffffff
# 1138805  8065fffffffffff  81653ffffffffff  826507fffffffff  836505fffffffff
# 1138807  802ffffffffffff  812f7ffffffffff  822f5ffffffffff  832f5afffffffff
#
#                  h3_res4          h3_res5
# 0        84194dbffffffff  85194daffffffff
# 4        84392d9ffffffff  85392d9bfffffff
# 5        84694edffffffff  85694ec3fffffff
# 7        848d809ffffffff  858d8083fffffff
# 15       8465051ffffffff  8565050bfffffff
# ...                  ...              ...
# 1138775  8428de1ffffffff  8528de8ffffffff
# 1138779  841f99dffffffff  851f99d7fffffff
# 1138783  848c107ffffffff  858c1073fffffff
# 1138805  8465057ffffffff  85650573fffffff
# 1138807  842f5a3ffffffff  852f5aaffffffff
#
# [192549 rows x 19 columns]

# %% [markdown]
# # Prune predictions

# %%
def pruned(preds, distances, n_to_prune=10):
    """
    prune to closest top N entities
    """
    preds_new = preds.copy()
    n = min(len(preds), n_to_prune)
    idx = np.argpartition(distances, n - 1)[:n]
    return preds_new[idx]

# %%
def eliminate_gts(preds, distances, gts):
    preds, distances, gts = preds.copy(), distances.copy(), gts.copy()
    mask = np.ones(len(preds), bool)

    for gt in gts:
        idx = np.argwhere(preds == gt).reshape(-1)
        if len(idx) > 0:
            mask[idx] = 0

    return preds[mask], distances[mask]

# %%
np.random.randint(0, 100, 3)
# Out:
# array([13,  6, 10])

# %%
def make_pair_dataset(preds_df, train_df, n_negatives=6, n_to_prune=10, monitor_iter=100):
    np.random.seed(CFG.RANDOM_SEED)

    preds_list = preds_df["preds"].to_numpy()
    distances_list = preds_df["distances"].to_numpy()
    ids_list = preds_df["id"].to_numpy()

    poi2gts = train_df.groupby("point_of_interest").agg(gt=("id", lambda x: list(x)))["gt"].to_dict()    
    id2poi = train_df.set_index("id")["point_of_interest"].to_dict()

    results = []
    for i, (id, preds, distances) in enumerate(tqdm(zip(ids_list, preds_list, distances_list), total=len(ids_list))):
        preds, distances = preds.copy(), distances.copy()
        gts = poi2gts[id2poi[id]]
        
        # extract Top-N closest false positives as negative candidates
        preds, distances = eliminate_gts(preds, distances, gts)
        n_pruned = min(len(preds), n_to_prune)
        preds = pruned(preds, distances, n_to_prune=n_pruned)

        gts_set = set(gts)
        preds_set = set(preds)

        # sample positive pair
        tp_others = np.array(list(gts_set.difference(set([id]))))
        pos_idx = np.random.randint(len(tp_others))
        positive = tp_others[pos_idx]
        results.append((id, positive, 1))

        # sample negative pair
        fps = np.array(list(preds_set.difference(gts_set)))
        if len(fps) > 0:
            n_samples = min(len(fps), n_negatives)
            neg_idxs = np.random.randint(0, len(fps), n_samples)
            negatives = fps[neg_idxs]
            for negative in negatives:
                results.append((id, negative, 0))

        if monitor_iter > 0 and i % monitor_iter == 0:
            print("=" * 80)
            print(f"positive pair: ({id}, {positive})")
            print(f"negative pair: ({id}, {negative})")

            # visualize text
            base_text = train_df.query("id == @id")["name"].item()
            pos_text = train_df.query("id == @positive")["name"].item()
            print(f"positive sentences pair: (\"{base_text}\", \"{pos_text}\")")

            if len(fps) > 0:
                neg_text = train_df.query("id == @negative")["name"].item()
                print(f"positive sentences pair: (\"{base_text}\", \"{neg_text}\")")
    results_df = pd.DataFrame(dict(zip(["id1", "id2", "matched"], zip(*results))))
    return results_df

# %%
results_dev_df = make_pair_dataset(preds_dev_df, train_dev, n_negatives=CFG.N_NEGATIVES, n_to_prune=CFG.N_CLOSEST, monitor_iter=1000)
# Out:
#   0%|          | 0/192549 [00:00<?, ?it/s]
# ================================================================================
# positive pair: (E_4544b36e5c2b88, E_5f9804714e0bc9)
# negative pair: (E_4544b36e5c2b88, E_a63073ab2c7675)
# positive sentences pair: ("krystal height", "island glades-krystal heights")
# positive sentences pair: ("krystal height", "klia reclaim baggage carousel f")
# ================================================================================
# positive pair: (E_d863ef04e80ae8, E_ce8e20f64221ba)
# negative pair: (E_d863ef04e80ae8, E_752eaaf69615bc)
# positive sentences pair: ("บันดาหยา รีสอร์ท", "bundhaya resort")
# positive sentences pair: ("บันดาหยา รีสอร์ท", "บ้านโอบฟ้า รีสอร์ท")
# ================================================================================
# positive pair: (E_e543453375b402, E_c8ef4882faa979)
# negative pair: (E_e543453375b402, E_14fd5dfa24d4e3)
# positive sentences pair: ("school of bussiness engineering entrepreneurship (ppit)", "school of business, universiti malaysia perlis")
# positive sentences pair: ("school of bussiness engineering entrepreneurship (ppit)", "smu school of economics (soe)")
# ================================================================================
# positive pair: (E_26399a70715de9, E_62ef238875d773)
# negative pair: (E_26399a70715de9, E_ef4597ad92c365)
# positive sentences pair: ("新顺美食中心coffeeshop", "新顺美食中心")
# positive sentences pair: ("新顺美食中心coffeeshop", "สุริยากาแฟ (suriya coffee)")
# ================================================================================
# positive pair: (E_5672d9a2760114, E_57f565921df7a5)
# negative pair: (E_5672d9a2760114, E_799a2248076125)
# positive sentences pair: ("bored vill.", "temasek secondary school")
# positive sentences pair: ("bored vill.", "vithita animation")
# ================================================================================
# positive pair: (E_1d78f575c37bda, E_d91fdb1b5b1ce0)
# negative pair: (E_1d78f575c37bda, E_37ca6f4a14eb24)
# positive sentences pair: ("peaberries coffee", "peaberries coffee bean || binlha 4")
# positive sentences pair: ("peaberries coffee", "blackcanyon coffee")
# ================================================================================
# positive pair: (E_b2a5e06dbab8be, E_9593d30d44ec25)
# negative pair: (E_b2a5e06dbab8be, E_5ae2bf6f06ed18)
# positive sentences pair: ("audi c, segi university college", "auditorium c, segi university college")
# positive sentences pair: ("audi c, segi university college", "segi uc class r2.1")
# ================================================================================
# positive pair: (E_6539b840f642a1, E_7eabc01d7cac67)
# negative pair: (E_6539b840f642a1, E_3f0af6ee95c7fd)
# positive sentences pair: ("restoran dju", "d'ju cafe")
# positive sentences pair: ("restoran dju", "restoran anamuda")
# ================================================================================
# positive pair: (E_037c17e8426250, E_25ce45b8f96094)
# negative pair: (E_037c17e8426250, E_feab2e1e2caed4)
# positive sentences pair: ("tuttifrutti , ou", "tutti frutti 1 utama")
# positive sentences pair: ("tuttifrutti , ou", "d'amour beuty @nex")
# ================================================================================
# positive pair: (E_f513e113a6c63e, E_05d9717f573d7e)
# negative pair: (E_f513e113a6c63e, E_e04c8db0646675)
# positive sentences pair: ("language center (elit)", "elit language centre")
# positive sentences pair: ("language center (elit)", "global learning center")
# ================================================================================
# positive pair: (E_87a4ce40fce87d, E_4eb390111a0fb1)
# negative pair: (E_87a4ce40fce87d, E_f4bff47b6b37de)
# positive sentences pair: ("nuh ward 47", "national university hospital (nuh) ward 47")
# positive sentences pair: ("nuh ward 47", "ward 5e-007")
# ================================================================================
# positive pair: (E_6a496dd40f5ce3, E_c0cb2901cc6221)
# negative pair: (E_6a496dd40f5ce3, E_a4ab0164368d36)
# positive sentences pair: ("es goyobod kliningan gokil", "es goyobod gokil")
# positive sentences pair: ("es goyobod kliningan gokil", "gor saparua")
# ================================================================================
# positive pair: (E_70d33625e9fa2c, E_47746578959305)
# negative pair: (E_70d33625e9fa2c, E_30ffd267f6616d)
# positive sentences pair: ("ikuze, lippo mall kemang village", "ikuze kemang village")
# positive sentences pair: ("ikuze, lippo mall kemang village", "cinemaxx lippo mall kuta")
# ================================================================================
# positive pair: (E_71b0f4171f0dfa, E_b9a448319eb9e3)
# negative pair: (E_71b0f4171f0dfa, E_41747e9cc1b407)
# positive sentences pair: ("pepper lunch taman anggrek mall", "paper lunch")
# positive sentences pair: ("pepper lunch taman anggrek mall", "a & w, mall taman anggrek")
# ================================================================================
# positive pair: (E_81151cb729e82e, E_39a03753104398)
# negative pair: (E_81151cb729e82e, E_aa1d494266836c)
# positive sentences pair: ("century healthcare carrefour lebak bulus", "century healthcare carrefour")
# positive sentences pair: ("century healthcare carrefour lebak bulus", "aesthetic clinic & breast center rs. pondok indah")
# ================================================================================
# positive pair: (E_2b1a9e13c6939c, E_e69d47583555a5)
# negative pair: (E_2b1a9e13c6939c, E_3582945ec398ec)
# positive sentences pair: ("kfc graha smkg", "kfc kelapa gading")
# positive sentences pair: ("kfc graha smkg", "kfc gatsu")
# ================================================================================
# positive pair: (E_58dc0d02066106, E_1cf8bc5074642f)
# negative pair: (E_58dc0d02066106, E_34e3bf0a337ed1)
# positive sentences pair: ("rosso' micro roastery pasar modern serpong", "rosso' micro roastery")
# positive sentences pair: ("rosso' micro roastery pasar modern serpong", "roti cafe bread & coffee")
# ================================================================================
# positive pair: (E_7c881952dce930, E_e63567edf80d01)
# negative pair: (E_7c881952dce930, E_4b11acbaf84f3a)
# positive sentences pair: ("transmedia", "balkon belakang lantai 8 trans tv")
# positive sentences pair: ("transmedia", "upinet multimedia learning resources center")
# ================================================================================
# positive pair: (E_cd8cf0703bf270, E_5282e7561b6a79)
# negative pair: (E_cd8cf0703bf270, E_7ef81869379ea3)
# positive sentences pair: ("km 32 rest area tol cipularang", "rest area km 32")
# positive sentences pair: ("km 32 rest area tol cipularang", "rest area km 147")
# ================================================================================
# positive pair: (E_ec42247de81f4f, E_3c16635af849d2)
# negative pair: (E_ec42247de81f4f, E_b21d3d17802303)
# positive sentences pair: ("denime bar", "denime juice bar")
# positive sentences pair: ("denime bar", "sobber bar's")
# ================================================================================
# positive pair: (E_418f44d88d8d7c, E_0e3fda55fdbc6a)
# negative pair: (E_418f44d88d8d7c, E_3041524ef60614)
# positive sentences pair: ("stasiun depok lama", "stasiun kereta api depok")
# positive sentences pair: ("stasiun depok lama", "stasiun kuripan")
# ================================================================================
# positive pair: (E_c8ec3345bfff1f, E_6fd1bd3b339f3d)
# negative pair: (E_c8ec3345bfff1f, E_0546c3a732b182)
# positive sentences pair: ("terowongan monas", "monunen nasional")
# positive sentences pair: ("terowongan monas", "woolloomooloo")
# ================================================================================
# positive pair: (E_8caac5a66b7ff8, E_0e537442173ebb)
# negative pair: (E_8caac5a66b7ff8, E_ffcc996f96e410)
# positive sentences pair: ("silenos cafe", "sillenos nargile cafe")
# positive sentences pair: ("silenos cafe", "neokhora cafe")
# ================================================================================
# positive pair: (E_97c924e3e7fd9b, E_da22fc57219fe1)
# negative pair: (E_97c924e3e7fd9b, E_e9f4b522fcc97d)
# positive sentences pair: ("oviya patisserie & cafe", "ovi̇ya pasta & cafe")
# positive sentences pair: ("oviya patisserie & cafe", "etiler café & patisserie")
# ================================================================================
# positive pair: (E_e4307c68aa2859, E_c4f7ddfd0c73cd)
# negative pair: (E_e4307c68aa2859, E_2e6330f49db3d3)
# positive sentences pair: ("ordu emniyet müdürlüğü asayiş sube", "ordu i̇l emniyet müdürlüğü")
# positive sentences pair: ("ordu emniyet müdürlüğü asayiş sube", "erbaa ilçe emliyet müdürlüğü")
# ================================================================================
# positive pair: (E_66c6b5368918fb, E_7414635ea9cbab)
# negative pair: (E_66c6b5368918fb, E_46429ef8afe41b)
# positive sentences pair: ("ng kütahya serami̇k", "kütahya seramik")
# positive sentences pair: ("ng kütahya serami̇k", "kütahya cumartesi pazarı")
# ================================================================================
# positive pair: (E_6f5f2321aa9ee4, E_90e69d03aeaf05)
# negative pair: (E_6f5f2321aa9ee4, E_fcb1a8a3a34f97)
# positive sentences pair: ("maltepe üniversitesi tıp fakültesi acil servisi", "maltepe üniversitesi tıp fakültesi hastanesi acil servis")
# positive sentences pair: ("maltepe üniversitesi tıp fakültesi acil servisi", "sanko üniversitesi tıp fakültesi")
# ================================================================================
# positive pair: (E_eb47bd32774b89, E_e21991f2bfe356)
# negative pair: (E_eb47bd32774b89, E_f10a4c1492005d)
# positive sentences pair: ("kahve ateşi exclusive gourmet", "kahve ateşi & motto")
# positive sentences pair: ("kahve ateşi exclusive gourmet", "yeni kaplica osmanli suit")
# ================================================================================
# positive pair: (E_7f99cc6e404402, E_9f2e189e4b5061)
# negative pair: (E_7f99cc6e404402, E_f7e046faab6261)
# positive sentences pair: ("my cabaret", "cabaret by soner olgun")
# positive sentences pair: ("my cabaret", "frame music club")
# ================================================================================
# positive pair: (E_5a87e784a36bcc, E_359c100c4683b3)
# negative pair: (E_5a87e784a36bcc, E_38b7004b366c0e)
# positive sentences pair: ("caddebostan bafetto", "bafetto")
# positive sentences pair: ("caddebostan bafetto", "bahçeli bilardo")
# ================================================================================
# positive pair: (E_1e8f5cb3adfcd1, E_9d83a13bb72084)
# negative pair: (E_1e8f5cb3adfcd1, E_a5a4ed0280f5ca)
# positive sentences pair: ("yeşilkent düğün salonu önü", "yeşilkent düğün salonu")
# positive sentences pair: ("yeşilkent düğün salonu önü", "tek taş düğün salonu")
# ================================================================================
# positive pair: (E_a1c2dd998d0037, E_70e99092abd0a4)
# negative pair: (E_a1c2dd998d0037, E_ea192dd0b31de6)
# positive sentences pair: ("ulaş tour", "ulaş sunset tour")
# positive sentences pair: ("ulaş tour", "i̇nflow travel summit")
# ================================================================================
# positive pair: (E_2054584d36c771, E_6c1aea3be2ce66)
# negative pair: (E_2054584d36c771, E_ad3682e398175c)
# positive sentences pair: ("los angeles airport", "los angeles international airport lax")
# positive sentences pair: ("los angeles airport", "antalya airport (ayt)")
# ================================================================================
# positive pair: (E_b64aed69a0985f, E_cf2f5eaedf21ed)
# negative pair: (E_b64aed69a0985f, E_eb2c5c7d274cce)
# positive sentences pair: ("pattaya kart speedway", "pattaya kart")
# positive sentences pair: ("pattaya kart speedway", "krungthep kreetha golf course (สนามกอล์ฟกรุงเทพกรีฑา)")
# ================================================================================
# positive pair: (E_1638944728875d, E_11ee16138123a7)
# negative pair: (E_1638944728875d, E_6f538ed751a75c)
# positive sentences pair: ("ก๋วยเตี๋ยวลูกชิ้นปลา แซว", "แซว (zaew)")
# positive sentences pair: ("ก๋วยเตี๋ยวลูกชิ้นปลา แซว", "เรวรรณ อร้ญฯ")
# ================================================================================
# positive pair: (E_69586540791a50, E_6900509af01741)
# negative pair: (E_69586540791a50, E_4e3836c00171a1)
# positive sentences pair: ("bbq plaza the mall ngamwongwan", "barbqplaza")
# positive sentences pair: ("bbq plaza the mall ngamwongwan", "bbq plaza siam center")
# ================================================================================
# positive pair: (E_ca7990b1db04b0, E_9b0c32a8169488)
# negative pair: (E_ca7990b1db04b0, E_0f0a60af73af32)
# positive sentences pair: ("kyo dai tei (เคียวไดเต)", "ร้านเคียวไดเต")
# positive sentences pair: ("kyo dai tei (เคียวไดเต)", "ร้านข้าวหมูแดง(khao moo dang)")
# ================================================================================
# positive pair: (E_e2695142fe9dd6, E_c352628bdacb56)
# negative pair: (E_e2695142fe9dd6, E_68c5028092d908)
# positive sentences pair: ("นมสต namasata", "นมสต | namasata @ buriram")
# positive sentences pair: ("นมสต namasata", "โรงพยาบาลเปาโลเมโมเรียล รังสิต")
# ================================================================================
# positive pair: (E_4b6bcde8acb73c, E_9681ad710f3226)
# negative pair: (E_4b6bcde8acb73c, E_f9ee7292a4c229)
# positive sentences pair: ("บ้านบางอ้อ (baan bang aor)", "กาแฟบ้านบางอ้อ")
# positive sentences pair: ("บ้านบางอ้อ (baan bang aor)", "บ้านบางเขน (baan bangkhen)")
# ================================================================================
# positive pair: (E_0c6e37ab66f81b, E_04bfb9492673e1)
# negative pair: (E_0c6e37ab66f81b, E_4a8814317a2c8e)
# positive sentences pair: ("cimb thai bank@ตลาดยิ่งเจริญ", "cimb bank @sapan mai")
# positive sentences pair: ("cimb thai bank@ตลาดยิ่งเจริญ", "cimb thai โลตัสวังหิน")
# ================================================================================
# positive pair: (E_d929c22a0222eb, E_469547643f9e79)
# negative pair: (E_d929c22a0222eb, E_a84d6c9ba58cd9)
# positive sentences pair: ("เซ็นทริค ติวานนท์สเตชั่น (centric tiwanon station)", "site centric ติวานนท์")
# positive sentences pair: ("เซ็นทริค ติวานนท์สเตชั่น (centric tiwanon station)", "ผาลาด ตะวันรอน (palaad tawanron)")
# ================================================================================
# positive pair: (E_ee58c705827c35, E_18961a21c987de)
# negative pair: (E_ee58c705827c35, E_cda2b1bfdceb8b)
# positive sentences pair: ("อาคาร 80 ปี", "อาคาร80ปีราคา200ล้านย่านบางพลัด")
# positive sentences pair: ("อาคาร 80 ปี", "หน้าห้องประชุม 40 ปี คณะศึกษาศาสตร์ มหาวิทยาลัยเชียงใหม่")
# ================================================================================
# positive pair: (E_8e7690da207026, E_053869a3ad294a)
# negative pair: (E_8e7690da207026, E_441eae4b1a4ffe)
# positive sentences pair: ("สนามเทนนิสแสนแสบ", "คอร์ทเทนนิส สวนแสนแสบ")
# positive sentences pair: ("สนามเทนนิสแสนแสบ", "เดอะริช")
# ================================================================================
# positive pair: (E_598e14af053e95, E_7906f85b907176)
# negative pair: (E_598e14af053e95, E_61c25256570089)
# positive sentences pair: ("東京ディズニーランドホテル (tokyo disneyland hotel)", "bell desk（ディズニーランドホテル）")
# positive sentences pair: ("東京ディズニーランドホテル (tokyo disneyland hotel)", "東京ドームシティホール楽屋")
# ================================================================================
# positive pair: (E_6574d0c667fae4, E_8eb0776960496e)
# negative pair: (E_6574d0c667fae4, E_42980f6e19dbd5)
# positive sentences pair: ("中国料理長秀龍", "長秀龍 新座店")
# positive sentences pair: ("中国料理長秀龍", "中国料理 川虎")
# ================================================================================
# positive pair: (E_df70ea04e81d72, E_9d6fdf2d116cd4)
# negative pair: (E_df70ea04e81d72, E_5c162980f884fb)
# positive sentences pair: ("yokohama creativecity center", "ycc ヨコハマ創造都市センター")
# positive sentences pair: ("yokohama creativecity center", "the three broomsticks at universal studio japan")
# ================================================================================
# positive pair: (E_13e7e18d736a97, E_1b1efbdcae67b2)
# negative pair: (E_13e7e18d736a97, E_6b8650cbe48388)
# positive sentences pair: ("コルレオーネカフェ / corleone cafe pancake & grill", "corleone cafe pancake & grill")
# positive sentences pair: ("コルレオーネカフェ / corleone cafe pancake & grill", "cafepit")
# ================================================================================
# positive pair: (E_ba59c48980aeec, E_7672e5da696f32)
# negative pair: (E_ba59c48980aeec, E_cfdece65faf922)
# positive sentences pair: ("渋谷ヒカリエb1 授乳室", "渋谷ヒカリエ (shibuya hikarie)")
# positive sentences pair: ("渋谷ヒカリエb1 授乳室", "ザ・ボディショップ 新越谷ヴァリエ店")
# ================================================================================
# positive pair: (E_30d766c93f4b55, E_0ff57c802b433b)
# negative pair: (E_30d766c93f4b55, E_28cd71ebec83a8)
# positive sentences pair: ("ホルモン本舗 輪倶", "輪倶御内臓 大宮店")
# positive sentences pair: ("ホルモン本舗 輪倶", "ホテルタウン本町")
# ================================================================================
# positive pair: (E_6c55c67f3302c1, E_08ccd33d585691)
# negative pair: (E_6c55c67f3302c1, E_700317394328b9)
# positive sentences pair: ("道しるべ", "題目塔道標")
# positive sentences pair: ("道しるべ", "道満グランド")
# ================================================================================
# positive pair: (E_26e46a3ae23198, E_08cc83f02c5a2b)
# negative pair: (E_26e46a3ae23198, E_e21b85ef9f6625)
# positive sentences pair: ("tarantella da luigi (タランテッラ ダ ルイジ)", "tarantella da luigi")
# positive sentences pair: ("tarantella da luigi (タランテッラ ダ ルイジ)", "ダイハツ")
# ================================================================================
# positive pair: (E_eb7429e44fa219, E_7426e9f00d403c)
# negative pair: (E_eb7429e44fa219, E_8a655b9c74cb78)
# positive sentences pair: ("mud pro shop & school", "make-up designory (mud)")
# positive sentences pair: ("mud pro shop & school", "city academy hackney")
# ================================================================================
# positive pair: (E_4e8885e9054853, E_24d93cc73ce90a)
# negative pair: (E_4e8885e9054853, E_5d881ff71e22f0)
# positive sentences pair: ("uea library floor 00", "uea library - 3 floor group study")
# positive sentences pair: ("uea library floor 00", "campus-bibliothek")
# ================================================================================
# positive pair: (E_943de2bc2377df, E_6cd3cf2de9893d)
# negative pair: (E_943de2bc2377df, E_37c2ff0e747cdd)
# positive sentences pair: ("bushy park", "bushey park")
# positive sentences pair: ("bushy park", "the dinosaur park")
# ================================================================================
# positive pair: (E_bdba85c15bf297, E_178d4ffa86361e)
# negative pair: (E_bdba85c15bf297, E_af2266a45be9e1)
# positive sentences pair: ("urbanest king's cross", "urbanest kings cross")
# positive sentences pair: ("urbanest king's cross", "nike central king's cross")
# ================================================================================
# positive pair: (E_a7d6ee257b323a, E_864e420055b888)
# negative pair: (E_a7d6ee257b323a, E_3b2a8e40ea18a0)
# positive sentences pair: ("juice box", "juice box london")
# positive sentences pair: ("juice box", "bonusbox hq")
# ================================================================================
# positive pair: (E_39fa71950cc138, E_89b595a8d84604)
# negative pair: (E_39fa71950cc138, E_c58c1b1f092c48)
# positive sentences pair: ("noxx antwerp", "noxx antwerpen")
# positive sentences pair: ("noxx antwerp", "halte antwerpen provinciehuis")
# ================================================================================
# positive pair: (E_00be437c9e3cda, E_91adb9697b82c5)
# negative pair: (E_00be437c9e3cda, E_094f9c0f45256e)
# positive sentences pair: ("ascot racecourse", "royal ascot")
# positive sentences pair: ("ascot racecourse", "roadkill festival")
# ================================================================================
# positive pair: (E_eeee216491038e, E_36dfec9d89368c)
# negative pair: (E_eeee216491038e, E_468b92af650ab9)
# positive sentences pair: ("alsancak astsubay misafirhanesi", "alsancak astsubay orduevi")
# positive sentences pair: ("alsancak astsubay misafirhanesi", "i̇zban alsancak i̇stasyonu")
# ================================================================================
# positive pair: (E_7de66a03aef3b7, E_5f1f22dbc33aba)
# negative pair: (E_7de66a03aef3b7, E_3b858b3b4bf47d)
# positive sentences pair: ("hucklrberry game room", "huckleberry game room")
# positive sentences pair: ("hucklrberry game room", "playmax bowling alley")
# ================================================================================
# positive pair: (E_3eb15aa44d9ec8, E_6cb7283c250bda)
# negative pair: (E_3eb15aa44d9ec8, E_aa0340ca187dc8)
# positive sentences pair: ("izbanda", "i̇zban şemikler i̇stasyonu")
# positive sentences pair: ("izbanda", "i̇ğdelik")
# ================================================================================
# positive pair: (E_76ea1913cfb0e7, E_5eb19a6c707965)
# negative pair: (E_76ea1913cfb0e7, E_c24184f9f99d7c)
# positive sentences pair: ("caramell cafe", "caramell cafe & pastahane i̇malathanesi")
# positive sentences pair: ("caramell cafe", "karayel cafe")
# ================================================================================
# positive pair: (E_9a2e2119e688c5, E_333d535fd2c32b)
# negative pair: (E_9a2e2119e688c5, E_fbb11400030637)
# positive sentences pair: ("baykal zeytinliği", "döndü baykal zeytinliği")
# positive sentences pair: ("baykal zeytinliği", "zeytinburnu açıkları")
# ================================================================================
# positive pair: (E_92285e1e6ce7a4, E_9bcf655a1a4554)
# negative pair: (E_92285e1e6ce7a4, E_afad27c4fe9b67)
# positive sentences pair: ("room 2505", "gural premier reception")
# positive sentences pair: ("room 2505", "room 6232")
# ================================================================================
# positive pair: (E_4c552698a9bdfa, E_6df74873f1cf03)
# negative pair: (E_4c552698a9bdfa, E_75484cbd824aa7)
# positive sentences pair: ("ege ports", "port of kusadasi")
# positive sentences pair: ("ege ports", "aswan dock | aswan, egy")
# ================================================================================
# positive pair: (E_5f7c01b324a2be, E_7a1d731b6a5a6e)
# negative pair: (E_5f7c01b324a2be, E_39ed2ca54aba0a)
# positive sentences pair: ("sate kambing pak mul", "sate kambing sumber pak mul")
# positive sentences pair: ("sate kambing pak mul", "sop kaki kambing & sate kambing dua saudara")
# ================================================================================
# positive pair: (E_379d500aa1c5c2, E_36eee2f80beffa)
# negative pair: (E_379d500aa1c5c2, E_98b377e4064d87)
# positive sentences pair: ("restoran renon", "restaurant renon")
# positive sentences pair: ("restoran renon", "restoran bambu kuning")
# ================================================================================
# positive pair: (E_6b07a89e362319, E_bb6ab31d8d8835)
# negative pair: (E_6b07a89e362319, E_649d7787a5d070)
# positive sentences pair: ("lazizaa chicken & pizza", "lazizaa chicken &pizza")
# positive sentences pair: ("lazizaa chicken & pizza", "chicken paikut")
# ================================================================================
# positive pair: (E_a777950bb5fa2c, E_bbe19f3083f4f0)
# negative pair: (E_a777950bb5fa2c, E_e2e3cadc1043d2)
# positive sentences pair: ("mlg coffeshop sumbersari", "mlg coffee shop & bebek mentok")
# positive sentences pair: ("mlg coffeshop sumbersari", "starbucks kemang")
# ================================================================================
# positive pair: (E_293b641afd83f1, E_fe8b9fecb170d7)
# negative pair: (E_293b641afd83f1, E_3a4f69c317ba14)
# positive sentences pair: ("bale raos", "bale raos jogja city mall")
# positive sentences pair: ("bale raos", "mie baso sari raos")
# ================================================================================
# positive pair: (E_77a25f327add79, E_537b6bacd414ae)
# negative pair: (E_77a25f327add79, E_2a44f8e1d3ba78)
# positive sentences pair: ("warung degan bakar", ""warung degan bakar \"barokah\""")
# positive sentences pair: ("warung degan bakar", "depan polda bawah makam pahlawan")
# ================================================================================
# positive pair: (E_aba7da4107c6ee, E_bee44b261c5930)
# negative pair: (E_aba7da4107c6ee, E_74e29459b623e7)
# positive sentences pair: ("sat pjr polda jateng", "polda jawa tengah")
# positive sentences pair: ("sat pjr polda jateng", "kawasan parkir barat prj")
# ================================================================================
# positive pair: (E_d23e4807036009, E_4863d4c6c131a9)
# negative pair: (E_d23e4807036009, E_83eb16354ccb79)
# positive sentences pair: ("serenity boutique", "serenity")
# positive sentences pair: ("serenity boutique", "hillside serenity beach")
# ================================================================================
# positive pair: (E_7dd9ade59a36c0, E_33b987a4fbbd56)
# negative pair: (E_7dd9ade59a36c0, E_45ab415ed2fd06)
# positive sentences pair: ("atatürk havalimanı dış hatlar terminali", "dış hatlar - teras")
# positive sentences pair: ("atatürk havalimanı dış hatlar terminali", "atatürk havalimanı i̇ç hatlar geliş")
# ================================================================================
# positive pair: (E_75d02630148162, E_e776f5f5f43893)
# negative pair: (E_75d02630148162, E_7871403fa62cca)
# positive sentences pair: ("limonata", "limonata mutfak & bar")
# positive sentences pair: ("limonata", "pecora nera")
# ================================================================================
# positive pair: (E_af070baef6e453, E_a11b19a91c600b)
# negative pair: (E_af070baef6e453, E_dcbfccffe215bc)
# positive sentences pair: ("13 kasım stadı", "13 kasım")
# positive sentences pair: ("13 kasım stadı", "aydınspor stadı")
# ================================================================================
# positive pair: (E_f5334b2000c86d, E_6b5b915689c6f8)
# negative pair: (E_f5334b2000c86d, E_3b44f5354daecf)
# positive sentences pair: ("le salon de coiffure & beautē", "le salon hair nails body")
# positive sentences pair: ("le salon de coiffure & beautē", "salon santal")
# ================================================================================
# positive pair: (E_0a06e65d1251eb, E_520897babbb304)
# negative pair: (E_0a06e65d1251eb, E_e9a792a45aef8a)
# positive sentences pair: ("can ocakbaşı ve dürüm evi", "can durum evi")
# positive sentences pair: ("can ocakbaşı ve dürüm evi", "i̇ki çılgin dürümcü")
# ================================================================================
# positive pair: (E_b23803d1805915, E_9ab07e1a283e27)
# negative pair: (E_b23803d1805915, E_f3c6dc23e3b412)
# positive sentences pair: ("east market milano", "east market")
# positive sentences pair: ("east market milano", "auditorium di milano")
# ================================================================================
# positive pair: (E_be7224d5e36891, E_9dfb458da2af74)
# negative pair: (E_be7224d5e36891, E_c213a40e85879b)
# positive sentences pair: ("lederwaren lenaerts", "lenaerts")
# positive sentences pair: ("lederwaren lenaerts", "gommans chrysantenkwekerij")
# ================================================================================
# positive pair: (E_b8f45457a4aa0e, E_282807bfbb94bf)
# negative pair: (E_b8f45457a4aa0e, E_d43279ffcc86cd)
# positive sentences pair: ("la muraille du phenix", "la muraille du phénix")
# positive sentences pair: ("la muraille du phenix", "le pont des artistes, france inter")
# ================================================================================
# positive pair: (E_ce9c4ed20b6385, E_a79c2b632c403f)
# negative pair: (E_ce9c4ed20b6385, E_0af5657bb3d572)
# positive sentences pair: ("hôtel de région", "hôtel de région auvergne-rhône-alpes")
# positive sentences pair: ("hôtel de région", "hotel de police")
# ================================================================================
# positive pair: (E_0f120b8e98a236, E_df037bea045b66)
# negative pair: (E_0f120b8e98a236, E_1addef860fbe09)
# positive sentences pair: ("eleganzza by gina gino - sb arcueil", "eleganzza by gina gino")
# positive sentences pair: ("eleganzza by gina gino - sb arcueil", "maze by gordon ramsay")
# ================================================================================
# positive pair: (E_9be95c2dd64faa, E_b5ef6a475aa20f)
# negative pair: (E_9be95c2dd64faa, E_4e0d1a1e9afc2a)
# positive sentences pair: ("court suzanne lenglen", "porte suzanne lenglen")
# positive sentences pair: ("court suzanne lenglen", "tennis 2000")
# ================================================================================
# positive pair: (E_404ee3849b3a48, E_bf0ff12309e350)
# negative pair: (E_404ee3849b3a48, E_4bb3d1fa86b253)
# positive sentences pair: ("викина растяжечка", "кенга | kenga")
# positive sentences pair: ("викина растяжечка", "мужская раздевалка")
# ================================================================================
# positive pair: (E_3052bd73527487, E_5d9bf2cfb6147f)
# negative pair: (E_3052bd73527487, E_48c226482f10df)
# positive sentences pair: ("автомойка на азс вр", "bp мойка")
# positive sentences pair: ("автомойка на азс вр", "автомойка (химчистка, полировка)")
# ================================================================================
# positive pair: (E_ac3444e85de1a8, E_908c3b37d2cc40)
# negative pair: (E_ac3444e85de1a8, E_23dc8efd4817b5)
# positive sentences pair: ("fresh cafe (world bank)", "офис macdonalds")
# positive sentences pair: ("fresh cafe (world bank)", "lounge cafe santa-barbara")
# ================================================================================
# positive pair: (E_e011619848981f, E_717bb032e219eb)
# negative pair: (E_e011619848981f, E_a3be1a41d42638)
# positive sentences pair: ("американский реабилитационный центр", "клиника")
# positive sentences pair: ("американский реабилитационный центр", "центральная районная больница сухиничского района")
# ================================================================================
# positive pair: (E_29f6a1b673d81d, E_a9263864584f2a)
# negative pair: (E_29f6a1b673d81d, E_c0351e8b8ef97c)
# positive sentences pair: ("рынок на львовской", "привокзальный рынок на львовской")
# positive sentences pair: ("рынок на львовской", "речовий ринок")
# ================================================================================
# positive pair: (E_3b9b97017f64c8, E_e9d5948baecb9c)
# negative pair: (E_3b9b97017f64c8, E_1007087262652c)
# positive sentences pair: ("ピッツェリア・アッソ・ダ・ヤマグチ", "pizzeria asso da yamaguchi")
# positive sentences pair: ("ピッツェリア・アッソ・ダ・ヤマグチ", "ラ・タルタルギーナ")
# ================================================================================
# positive pair: (E_a19935dd55d669, E_e817d655ea0d25)
# negative pair: (E_a19935dd55d669, E_63db9490b86338)
# positive sentences pair: ("焼肉 俺の太陽", "俺の太陽")
# positive sentences pair: ("焼肉 俺の太陽", "ぶた丼のぶたはげ帯広本店")
# ================================================================================
# positive pair: (E_514d5f62779a6c, E_51b0316c9995c0)
# negative pair: (E_514d5f62779a6c, E_e08c272bdd6394)
# positive sentences pair: ("とんかつ めぐろ", "めぐろ")
# positive sentences pair: ("とんかつ めぐろ", "とんかつ keita")
# ================================================================================
# positive pair: (E_6ab659c7dc8605, E_ae245fb2ccf476)
# negative pair: (E_6ab659c7dc8605, E_81bc73d9f7df6e)
# positive sentences pair: ("双葉温泉 双葉の湯 男湯露天風呂内", "双葉温泉")
# positive sentences pair: ("双葉温泉 双葉の湯 男湯露天風呂内", "道の駅 風早の郷風和里")
# ================================================================================
# positive pair: (E_41b54abdaf4ead, E_2b7002eb95dfb7)
# negative pair: (E_41b54abdaf4ead, E_376b824c4000bc)
# positive sentences pair: ("長居植物園", "nagai botanical garden")
# positive sentences pair: ("長居植物園", "長嶋茂雄レリーフ")
# ================================================================================
# positive pair: (E_cd860d0874a52f, E_7da2fa25010b5c)
# negative pair: (E_cd860d0874a52f, E_cffd99931d757b)
# positive sentences pair: ("aeon mall kobekita", "イオンモール神戸北")
# positive sentences pair: ("aeon mall kobekita", "bay store")
# ================================================================================
# positive pair: (E_d022351335ce20, E_05fc72377af3c6)
# negative pair: (E_d022351335ce20, E_beccd04befefd0)
# positive sentences pair: ("らぁめん屋 麺たらこ", "麺たらこ")
# positive sentences pair: ("らぁめん屋 麺たらこ", "たこ焼 玉屋 本店")
# ================================================================================
# positive pair: (E_b51d057d5036c3, E_011e7a31199bcb)
# negative pair: (E_b51d057d5036c3, E_eb4a4dfb8b77c5)
# positive sentences pair: ("반포꽃시장", "강남고속터미널 꽃도매상가")
# positive sentences pair: ("반포꽃시장", "교보핫트렉스")
# ================================================================================
# positive pair: (E_3323bbfc520ee6, E_5c15ba2b549a2b)
# negative pair: (E_3323bbfc520ee6, E_4c101154b5e800)
# positive sentences pair: ("평촌역", "pheongchon station")
# positive sentences pair: ("평촌역", "도봉산역")
# ================================================================================
# positive pair: (E_f6bc01f63964a8, E_39264b99eefcf8)
# negative pair: (E_f6bc01f63964a8, E_7d4bf325858fef)
# positive sentences pair: ("bbq(수영점)", "다리집 수영점")
# positive sentences pair: ("bbq(수영점)", "대성정육식당")
# ================================================================================
# positive pair: (E_488cfe12566026, E_0a437ed4961b21)
# negative pair: (E_488cfe12566026, E_eba683e6d47973)
# positive sentences pair: ("moses f. rittenhouse public library", "lincoln public library moses rittenhouse branch")
# positive sentences pair: ("moses f. rittenhouse public library", "brooklyn public library - kings bay")
# ================================================================================
# positive pair: (E_0148e3868f7125, E_eeeee2f576d74d)
# negative pair: (E_0148e3868f7125, E_d187762e2f5c28)
# positive sentences pair: ("ohiohealth sports medicine center", "max sports medicine")
# positive sentences pair: ("ohiohealth sports medicine center", "community health center, inc.")
# ================================================================================
# positive pair: (E_334f5f8d2f0830, E_c1596103dc852a)
# negative pair: (E_334f5f8d2f0830, E_a43ce428e06682)
# positive sentences pair: ("winwholesale distribution center", "win wholesale")
# positive sentences pair: ("winwholesale distribution center", "towne center")
# ================================================================================
# positive pair: (E_363d710a6f0364, E_f307e1701651fe)
# negative pair: (E_363d710a6f0364, E_84bd7f19506f71)
# positive sentences pair: ("bullseye tavern (3286)", "bull's eye saloon and restaurant")
# positive sentences pair: ("bullseye tavern (3286)", "village tavern & grill")
# ================================================================================
# positive pair: (E_7c5d4104be46ca, E_6ae9c062da0047)
# negative pair: (E_7c5d4104be46ca, E_327c14bc2ea53d)
# positive sentences pair: ("chillum parl", "chillum park")
# positive sentences pair: ("chillum parl", "peppers")
# ================================================================================
# positive pair: (E_0450f5fb14adec, E_c10d87a210a0ca)
# negative pair: (E_0450f5fb14adec, E_817363956ce297)
# positive sentences pair: ("airport parking garage", "mht parking garage")
# positive sentences pair: ("airport parking garage", "the parking spot")
# ================================================================================
# positive pair: (E_df3bd7255ac884, E_bb6469bca8f0e5)
# negative pair: (E_df3bd7255ac884, E_c6fe0626ea49bd)
# positive sentences pair: ("falmouth waste management facility", "town of falmouth wastewater treatment facility")
# positive sentences pair: ("falmouth waste management facility", "marblehead recycling center")
# ================================================================================
# positive pair: (E_3f956dcfe6587f, E_9fb444750833af)
# negative pair: (E_3f956dcfe6587f, E_00b7f5e6b9af9d)
# positive sentences pair: ("new image", "new image laser hair removal")
# positive sentences pair: ("new image", "visionspace gallery")
# ================================================================================
# positive pair: (E_6fd13583fe8a41, E_7249aebc27091e)
# negative pair: (E_6fd13583fe8a41, E_d3b0872289d5b9)
# positive sentences pair: ("formula one driving school llc.", "formula one driving school")
# positive sentences pair: ("formula one driving school llc.", "luxsport motor group, llc")
# ================================================================================
# positive pair: (E_8fa91fb460fe3c, E_779ad71a8e453b)
# negative pair: (E_8fa91fb460fe3c, E_11e8110c8e5ccb)
# positive sentences pair: ("duuni", "duunis on tylsää")
# positive sentences pair: ("duuni", "oulun vapaaseurakunta")
# ================================================================================
# positive pair: (E_92e8b3296abadf, E_57dc6a83c3a18b)
# negative pair: (E_92e8b3296abadf, E_6784e399d664a9)
# positive sentences pair: ("василий петрович", "немецкий 40а")
# positive sentences pair: ("василий петрович", "михаил юрьевич")
# ================================================================================
# positive pair: (E_3aa1bd9b9334c5, E_90baf7c6d4e819)
# negative pair: (E_3aa1bd9b9334c5, E_29f5d24e0faf64)
# positive sentences pair: ("белки", "крестовский остров ( парк )")
# positive sentences pair: ("белки", "бублико")
# ================================================================================
# positive pair: (E_6909dff99b2221, E_b15f5d03bafbb7)
# negative pair: (E_6909dff99b2221, E_f33e36c935ffd9)
# positive sentences pair: ("pehkubaari", "pehku")
# positive sentences pair: ("pehkubaari", "biķernieku trase")
# ================================================================================
# positive pair: (E_ba45ffc0ba246e, E_898032eb2959ce)
# negative pair: (E_ba45ffc0ba246e, E_d81c4e25959b43)
# positive sentences pair: ("clean square big c", "klean square")
# positive sentences pair: ("clean square big c", "big c pangplee")
# ================================================================================
# positive pair: (E_6b9b98e46aa441, E_38f5b38880801c)
# negative pair: (E_6b9b98e46aa441, E_15b734f3c38c44)
# positive sentences pair: ("ก๋วยเตี๋ยวเนื้่อเจ๊เช็ง", "ก๊วยเตี๊ยวเนื้อเจ๊เช็ง")
# positive sentences pair: ("ก๋วยเตี๋ยวเนื้่อเจ๊เช็ง", "ก๋วยเตี๋ยวเรือท่าปรีชา")
# ================================================================================
# positive pair: (E_1e4eee8a2f343d, E_870bf1fe490739)
# negative pair: (E_1e4eee8a2f343d, E_5551601540e094)
# positive sentences pair: ("วัดรางบัวทอง @สุพรรณบุรี", "วัดรางบัวทอง （^人^）")
# positive sentences pair: ("วัดรางบัวทอง @สุพรรณบุรี", "ยอดก๋วยเตี๋ยวเป็ด@อุดร")
# ================================================================================
# positive pair: (E_9a411801ff9911, E_27aed778af88d4)
# negative pair: (E_9a411801ff9911, E_3bd29524fb7cd0)
# positive sentences pair: ("wangs tavern", "big wangs")
# positive sentences pair: ("wangs tavern", "marquis cocktail lounge")
# ================================================================================
# positive pair: (E_fc6eaec4ab63c7, E_02626f4dc4fec7)
# negative pair: (E_fc6eaec4ab63c7, E_b5ef46ce0a3b5c)
# positive sentences pair: ("kane spring checkpoint", "la migra checkpoint")
# positive sentences pair: ("kane spring checkpoint", "hearst castle morning room")
# ================================================================================
# positive pair: (E_24749fec1c6f0c, E_84b7b8957c14a5)
# negative pair: (E_24749fec1c6f0c, E_bebc202e0faf17)
# positive sentences pair: ("willy street co-op", "willy street co-op west")
# positive sentences pair: ("willy street co-op", "bobs inn")
# ================================================================================
# positive pair: (E_715f726165e32f, E_666806000e78fb)
# negative pair: (E_715f726165e32f, E_55c8944138c3dc)
# positive sentences pair: ("spa terminal gateway", "terminal getaway spa")
# positive sentences pair: ("spa terminal gateway", "terminal 1 exit 4a")
# ================================================================================
# positive pair: (E_77f2ba76693e25, E_202633b5c3ae3b)
# negative pair: (E_77f2ba76693e25, E_ac3ab39d9bfe6c)
# positive sentences pair: ("aluminum blanking", "aluminum blanking company, inc.")
# positive sentences pair: ("aluminum blanking", "metalworks")
# ================================================================================
# positive pair: (E_225b74de6d1fa2, E_ee9f2d7e65052b)
# negative pair: (E_225b74de6d1fa2, E_4447212a2dd1ea)
# positive sentences pair: ("pivnica merlon", "restoran merlon")
# positive sentences pair: ("pivnica merlon", "pirinççi sinan camii")
# ================================================================================
# positive pair: (E_982ca64d9e764b, E_7b8ea9507fb5dd)
# negative pair: (E_982ca64d9e764b, E_eeb3d6dca6f2ea)
# positive sentences pair: ("hope jazykovyservis.cz", "hope jazykový servis")
# positive sentences pair: ("hope jazykovyservis.cz", "łazienki krolewskie")
# ================================================================================
# positive pair: (E_78e8fb7189b413, E_da9cbcd6fee7bb)
# negative pair: (E_78e8fb7189b413, E_657ec3f3a42d15)
# positive sentences pair: ("centro de eventos coronado", "salón coronado")
# positive sentences pair: ("centro de eventos coronado", "centro de atención primaria a la salud")
# ================================================================================
# positive pair: (E_34fa882e2513c6, E_6b5d02e07c96a6)
# negative pair: (E_34fa882e2513c6, E_6a64dd130626bc)
# positive sentences pair: ("hertz return", "hertz avasa")
# positive sentences pair: ("hertz return", "parque delta")
# ================================================================================
# positive pair: (E_b7ce60f102e3b3, E_2ef28747791513)
# negative pair: (E_b7ce60f102e3b3, E_fecd399d537833)
# positive sentences pair: ("picnic medio maraton cdmx 2016", "medio maratón cdmx")
# positive sentences pair: ("picnic medio maraton cdmx 2016", "padre light tackle adventures")
# ================================================================================
# positive pair: (E_228afc018e9542, E_b384c0df0a3850)
# negative pair: (E_228afc018e9542, E_6c2213cac470ce)
# positive sentences pair: ("gateway garden heights", "gateway garden heights condominium")
# positive sentences pair: ("gateway garden heights", "edsa (pasay road underpass)")
# ================================================================================
# positive pair: (E_19afa210fa75bd, E_06d08349245fbe)
# negative pair: (E_19afa210fa75bd, E_0ce3b61a237147)
# positive sentences pair: ("rustan's kids", "rustan's")
# positive sentences pair: ("rustan's kids", "guilly's")
# ================================================================================
# positive pair: (E_b3d8d47702b44c, E_4e2ebecd178c0b)
# negative pair: (E_b3d8d47702b44c, E_26b8dd5deb9fcd)
# positive sentences pair: ("edeler kasab ve ocakbasi", "edeler kasap")
# positive sentences pair: ("edeler kasab ve ocakbasi", "özefe kasap şerkuteri")
# ================================================================================
# positive pair: (E_5575c09bc365e1, E_0a65c3475e6bc4)
# negative pair: (E_5575c09bc365e1, E_559f08c74083a8)
# positive sentences pair: ("dover seyir alani", "döver seyir terası")
# positive sentences pair: ("dover seyir alani", "ebe çamlığı kent ormanı")
# ================================================================================
# positive pair: (E_5637d684d672f1, E_92863c25990ee2)
# negative pair: (E_5637d684d672f1, E_1085988d6911a7)
# positive sentences pair: ("wiregrass", "wiregrass georgia technical college")
# positive sentences pair: ("wiregrass", "flintstone elementary")
# ================================================================================
# positive pair: (E_0218b946504f62, E_f120a116ceb6e5)
# negative pair: (E_0218b946504f62, E_444f30da61fbbf)
# positive sentences pair: ("mcallister", "mccalisters")
# positive sentences pair: ("mcallister", "mckenzie")
# ================================================================================
# positive pair: (E_fb48fa9b7da7a6, E_75cb5e24b236cc)
# negative pair: (E_fb48fa9b7da7a6, E_ecf683729ab4b0)
# positive sentences pair: ("kiğı mezarlığı", "kiğı erki çarşı mezarlığı")
# positive sentences pair: ("kiğı mezarlığı", "gölbaşı mezarlığı")
# ================================================================================
# positive pair: (E_a41339506d85ee, E_21bcd6caea4766)
# negative pair: (E_a41339506d85ee, E_1c3ca32bca47ae)
# positive sentences pair: ("çatak jandarma atış poligonu", "çatak i̇lçe jandarma komutanlığı")
# positive sentences pair: ("çatak jandarma atış poligonu", "çaldağ jandarma karakol komutanlığı")
# ================================================================================
# positive pair: (E_84807128956ca5, E_186a76fcb3c232)
# negative pair: (E_84807128956ca5, E_052ae6c8c52cd4)
# positive sentences pair: ("brush by lubna alomair", "brush salon")
# positive sentences pair: ("brush by lubna alomair", "chocobar albid3")
# ================================================================================
# positive pair: (E_17c61a47b23b4e, E_fc15c2a38ee560)
# negative pair: (E_17c61a47b23b4e, E_42ca12f379bbef)
# positive sentences pair: ("saudi credit bureau simah new head office", "simah | oasis granada towers")
# positive sentences pair: ("saudi credit bureau simah new head office", "al rajhi bank tower - head office")
# ================================================================================
# positive pair: (E_a1444efc54672a, E_fef4c4a94984f9)
# negative pair: (E_a1444efc54672a, E_6dbde15ff2a224)
# positive sentences pair: ("首页_gucci包价格多少钱-一比一原单a货奢侈品不", "首页_gucci的包包一般多少钱-一比一原单a货奢侈品过")
# positive sentences pair: ("首页_gucci包价格多少钱-一比一原单a货奢侈品不", "首页_gucci精仿鞋-一比一原单a货奢侈品连")
# ================================================================================
# positive pair: (E_55740d9e638f43, E_a845c7f09eb6c0)
# negative pair: (E_55740d9e638f43, E_e8d8fb535b86c7)
# positive sentences pair: ("src fitness center", "scott county fitness center")
# positive sentences pair: ("src fitness center", "fountainhead apartments fitness center")
# ================================================================================
# positive pair: (E_40385dfe3fb161, E_bf198033c2e031)
# negative pair: (E_40385dfe3fb161, E_6f2940145c323b)
# positive sentences pair: ("taste of são paulo", "taste of são paulo 4ª edição")
# positive sentences pair: ("taste of são paulo", "hotel transamérica são paulo")
# ================================================================================
# positive pair: (E_405fe92b2a871e, E_d0dd73addd9e4f)
# negative pair: (E_405fe92b2a871e, E_401ddf16af22ce)
# positive sentences pair: ("espaco onix", "espaço onix")
# positive sentences pair: ("espaco onix", "espaço raro estética")
# ================================================================================
# positive pair: (E_8d42f17cc5e116, E_7427858c248081)
# negative pair: (E_8d42f17cc5e116, E_51a6929283a6bd)
# positive sentences pair: ("iuse - ogle center", "ius ogle center 065")
# positive sentences pair: ("iuse - ogle center", "gcsu centennial center")
# ================================================================================
# positive pair: (E_d1fa56eb1c063d, E_b8b2647ed6b0bd)
# negative pair: (E_d1fa56eb1c063d, E_892d0462f66428)
# positive sentences pair: ("column capital", "column capital advisors")
# positive sentences pair: ("column capital", "board of trade")
# ================================================================================
# positive pair: (E_d3e508b1fc10e8, E_6dc0d3440c74b6)
# negative pair: (E_d3e508b1fc10e8, E_29b4714c3071da)
# positive sentences pair: ("großer stern", "berlin victory column")
# positive sentences pair: ("großer stern", "schauspiel leipzig große bühne")
# ================================================================================
# positive pair: (E_2aa3b6c02144d9, E_a6951f6916423c)
# negative pair: (E_2aa3b6c02144d9, E_5f713fc8adcb8c)
# positive sentences pair: ("reifencom gmbh bielefeld", "reifencom gmbh")
# positive sentences pair: ("reifencom gmbh bielefeld", "autohaus fritzsche gmbh")
# ================================================================================
# positive pair: (E_14856e154b99b5, E_4c1161cc7f2ddc)
# negative pair: (E_14856e154b99b5, E_596bf875f0af75)
# positive sentences pair: ("залізничний вокзал «дарниця»", "вокзал")
# positive sentences pair: ("залізничний вокзал «дарниця»", "станція «дарниця»")
# ...
# positive pair: (E_b8e3dd8aec7f7b, E_24583cbc2e5a3a)
# negative pair: (E_b8e3dd8aec7f7b, E_dd55b57ec893b9)
# positive sentences pair: ("cargo @ whitney peak hotel", "cargo")
# positive sentences pair: ("cargo @ whitney peak hotel", "marriott marquis salon 7")
# ================================================================================
# positive pair: (E_003f7353bc029f, E_268a5c3ab1f2c8)
# negative pair: (E_003f7353bc029f, E_7b53add4d29ecd)
# positive sentences pair: ("physics laboratory eben haezar ch. shs", "xii social 2 sma kr. eben haezar")
# positive sentences pair: ("physics laboratory eben haezar ch. shs", "fakultas pertanian, universitas tadulako")
# ================================================================================
# positive pair: (E_7f1948699cbc70, E_448279d832a206)
# negative pair: (E_7f1948699cbc70, E_680cc7965247a0)
# positive sentences pair: ("rm mangga dua", "mangga dua")
# positive sentences pair: ("rm mangga dua", "rm losari indah")
# ================================================================================
# positive pair: (E_dac38330c3fea2, E_50308e9e0cbabe)
# negative pair: (E_dac38330c3fea2, E_f52407f3556dde)
# positive sentences pair: ("博多道場", "dojo hakata 博多道場")
# positive sentences pair: ("博多道場", "山頂廣場")
# ================================================================================
# positive pair: (E_23d7444a9dac60, E_793a046b907506)
# negative pair: (E_23d7444a9dac60, E_14f15105f66446)
# positive sentences pair: ("花蓮門諾", "基督教門諾會醫院")
# positive sentences pair: ("花蓮門諾", "花蝶雅居 butterfly garden")
# ================================================================================
# positive pair: (E_beb39f5dbc09a3, E_37ae141f0e06ce)
# negative pair: (E_beb39f5dbc09a3, E_15208169b90030)
# positive sentences pair: ("o.c.a. san filippo neri", "ospedale san filippo neri")
# positive sentences pair: ("o.c.a. san filippo neri", ""spitalul militar de urgență \"dr. constantin papilian\""")
# ================================================================================
# positive pair: (E_c31853c1afdab1, E_4ba56479d55c95)
# negative pair: (E_c31853c1afdab1, E_45b2d5b43d3096)
# positive sentences pair: ("le méridien visconti rome", "le meridian visconti rome")
# positive sentences pair: ("le méridien visconti rome", "leclerc de hyeres")
# ================================================================================
# positive pair: (E_6bc5c1324de20c, E_c0ed9a41c4d00f)
# negative pair: (E_6bc5c1324de20c, E_9358b484b8f4d0)
# positive sentences pair: ("гимназия города дзержинска", "гимназия г. дзержинска")
# positive sentences pair: ("гимназия города дзержинска", "студия джаз-модерна людмилы квасневской")
# ================================================================================
# positive pair: (E_afcf63669c6c9e, E_1651fedce61e2d)
# negative pair: (E_afcf63669c6c9e, E_085045350bf0bb)
# positive sentences pair: ("friendly barber shop", "friendly barber")
# positive sentences pair: ("friendly barber shop", "the barber law firm")
# ================================================================================
# positive pair: (E_63cba82536a171, E_214239a827bd47)
# negative pair: (E_63cba82536a171, E_599a36f4c57627)
# positive sentences pair: ("味和居", "中華料理 味和居")
# positive sentences pair: ("味和居", "大和商店")
# ================================================================================
# positive pair: (E_9766480cb49bfe, E_b43c2aef4436af)
# negative pair: (E_9766480cb49bfe, E_a3e407d729ad19)
# positive sentences pair: ("medicina nuclear villela pedras", "clinica de medicina nuclear vilela pedras")
# positive sentences pair: ("medicina nuclear villela pedras", "centro médico caxias")
# ================================================================================
# positive pair: (E_36a87090590b07, E_3665afe14e979a)
# negative pair: (E_36a87090590b07, E_dd4f7fc357f14a)
# positive sentences pair: ("adirondack tubing adventures", "adirondack adventure center")
# positive sentences pair: ("adirondack tubing adventures", "brookfield zoo- pachyderms")
# ================================================================================
# positive pair: (E_469d7f43757572, E_ba0219a12ccf6f)
# negative pair: (E_469d7f43757572, E_642f5e97367c69)
# positive sentences pair: ("kirkland cemetery", "lakewood cemetery")
# positive sentences pair: ("kirkland cemetery", "lennar at hillcrest at the preserve")
# ================================================================================
# positive pair: (E_12c51dae326947, E_67194d10d5d972)
# negative pair: (E_12c51dae326947, E_cf4cd275c6458d)
# positive sentences pair: ("victrola cafe and roastery", "victrola coffee")
# positive sentences pair: ("victrola cafe and roastery", "barkada bakery cafe")
# ================================================================================
# positive pair: (E_04b430915c0f81, E_5fcfc081b69ebf)
# negative pair: (E_04b430915c0f81, E_ef578bcca014cc)
# positive sentences pair: ("restaurante olive", "olive tapas & restaurant")
# positive sentences pair: ("restaurante olive", "restaurante auga")
# ================================================================================
# positive pair: (E_19ab8f2daee0e8, E_52686ea69d8069)
# negative pair: (E_19ab8f2daee0e8, E_1697f0ea1f135d)
# positive sentences pair: ("atown", "a town")
# positive sentences pair: ("atown", "scooter's")
# ================================================================================
# positive pair: (E_b929d4c0a634a9, E_834592f2b9c8f5)
# negative pair: (E_b929d4c0a634a9, E_2f8d9f093109be)
# positive sentences pair: ("healing choices-natural healthcare clinic", "healing choices - natural healthcare clinic")
# positive sentences pair: ("healing choices-natural healthcare clinic", "terra health & wellness market")
# ================================================================================
# positive pair: (E_08e71050084785, E_5eca2652268872)
# negative pair: (E_08e71050084785, E_e4bc87d2e66c64)
# positive sentences pair: ("mustialan kievari ja wanha viljamakasiini", "mustialan kievari, vanha viljamakasiini")
# positive sentences pair: ("mustialan kievari ja wanha viljamakasiini", "костел св. михаила архангела")
# ================================================================================
# positive pair: (E_6e874005dcce63, E_41e90817af0d61)
# negative pair: (E_6e874005dcce63, E_390f3fad3a5a83)
# positive sentences pair: ("north central sports bar", "cowboys country st north central")
# positive sentences pair: ("north central sports bar", "frankie's sports bar & grill")
# ================================================================================
# positive pair: (E_7e929d43452ca6, E_83988180b2eee1)
# negative pair: (E_7e929d43452ca6, E_cafcd9e54f6c47)
# positive sentences pair: ("elite - khaleejiya complex", "elite institute for private training")
# positive sentences pair: ("elite - khaleejiya complex", "al-rihab complex")
# ================================================================================
# positive pair: (E_e8aafce736d151, E_1b04b730b433b0)
# negative pair: (E_e8aafce736d151, E_7c8ad36e45d0e9)
# positive sentences pair: ("xiangyin rd. tunnel (翔殷路隧道)", "xiangyin rd tunnel")
# positive sentences pair: ("xiangyin rd. tunnel (翔殷路隧道)", "地铁六道口站 subway liudaokou")
# ================================================================================
# positive pair: (E_d473245797bf8b, E_f5d27c57165f57)
# negative pair: (E_d473245797bf8b, E_39f450b3bbb81e)
# positive sentences pair: ("el khon", "el khon | الخن")
# positive sentences pair: ("el khon", "kling usta")
# ================================================================================
# positive pair: (E_3389335b893eee, E_dbab6ee744d470)
# negative pair: (E_3389335b893eee, E_5b1093f5770ebe)
# positive sentences pair: ("paviliun clara - rs. rk. charitas", "charitas pav. clara lat.5 512")
# positive sentences pair: ("paviliun clara - rs. rk. charitas", "dr. fransisca n. sugana sp.kk")
# ================================================================================
# positive pair: (E_23a575e5c459c3, E_c27585eaff7d90)
# negative pair: (E_23a575e5c459c3, E_58990de0133a5e)
# positive sentences pair: ("first abu dhabi bank / بنك أبوظبي الأول", "nbad المشرف مول")
# positive sentences pair: ("first abu dhabi bank / بنك أبوظبي الأول", "national bank of abu dhabi")
# ================================================================================
# positive pair: (E_0ee93f6e4ee77c, E_62cfb606fd3420)
# negative pair: (E_0ee93f6e4ee77c, E_edfbed2c851aa1)
# positive sentences pair: ("نان سنتی (سنگکی جاوید)", "نان سنگک سنتی")
# positive sentences pair: ("نان سنتی (سنگکی جاوید)", "استانداری آذربایجان غربی (معاونت امور مالی)")
# ================================================================================
# positive pair: (E_b01e3584123313, E_739a92c7c9b80a)
# negative pair: (E_b01e3584123313, E_5a62cc585086fc)
# positive sentences pair: ("компрессорный завод", "казань компресорный")
# positive sentences pair: ("компрессорный завод", "спортивный зал кольцова✖️💞")
# ================================================================================
# positive pair: (E_82c23a55598b8f, E_97d548a6b41a8f)
# negative pair: (E_82c23a55598b8f, E_f99ca88ca25b0f)
# positive sentences pair: ("lagarttu's", "lagarttu's hamburgueria & espetaria")
# positive sentences pair: ("lagarttu's", "galetos do mario")
# ================================================================================
# positive pair: (E_177b7464767a10, E_c6edf0a827a5ea)
# negative pair: (E_177b7464767a10, E_7efc6b0ced3ee2)
# positive sentences pair: ("ถ่ำตลอด อ.ทุ่งสง", "ถ้ำตลอด")
# positive sentences pair: ("ถ่ำตลอด อ.ทุ่งสง", "ติวรถตู้ กรุงเทพ-ระยอง")
# ================================================================================
# positive pair: (E_70b937e00c1b12, E_592f1e74afd616)
# negative pair: (E_70b937e00c1b12, E_7b0006689bc911)
# positive sentences pair: ("golden wok china buffet", "golden wok")
# positive sentences pair: ("golden wok china buffet", "happy garden buffet & grill")
# ================================================================================
# positive pair: (E_7b4f1ea94690ba, E_cf7164a8d35083)
# negative pair: (E_7b4f1ea94690ba, E_b6ad7ce4113604)
# positive sentences pair: ("dau falls", "da-o falls")
# positive sentences pair: ("dau falls", "binalayan hidden falls / triple drop falls")
# ================================================================================
# positive pair: (E_958b62c93fbd59, E_faf056e03a42e1)
# negative pair: (E_958b62c93fbd59, E_2b1384b06d5a44)
# positive sentences pair: ("little sams", "little sam's island & beach fun")
# positive sentences pair: ("little sams", "the spot where biggie smalls was shot and killed")
# ================================================================================
# positive pair: (E_f8f2c192e62ae6, E_a9c6d8f9334cc6)
# negative pair: (E_f8f2c192e62ae6, E_ba5e4dd33f20eb)
# positive sentences pair: ("ufrgs campus do vale", "universidade federal do rio grande do sul (ufrgs)")
# positive sentences pair: ("ufrgs campus do vale", "inst. edu. inf. pequeno aprendiz")
# ================================================================================
# positive pair: (E_b0dbfbf05631e2, E_30c0b453d027cc)
# negative pair: (E_b0dbfbf05631e2, E_065c1d886978a0)
# positive sentences pair: ("aire de saint-christoly", "aire de st christoly")
# positive sentences pair: ("aire de saint-christoly", "aire de poitou-charentes")
# ================================================================================
# positive pair: (E_52114ee607cdb9, E_dc47cafd8785f9)
# negative pair: (E_52114ee607cdb9, E_bd98f7b7bc229d)
# positive sentences pair: ("جامع الأميرة شهيدة (والدة الأمير متعب)", "جامع الأميرة شهيدة")
# positive sentences pair: ("جامع الأميرة شهيدة (والدة الأمير متعب)", "شاطىء الشعيبة")
# ================================================================================
# positive pair: (E_cc1740a304d162, E_2b6a8a36897e4f)
# negative pair: (E_cc1740a304d162, E_94cc6b5accf0d3)
# positive sentences pair: ("tad lo waterfall", "tadlo (falls)")
# positive sentences pair: ("tad lo waterfall", "แม่น้ำตกแม่กลาง (mae klang waterfall)")
# ================================================================================
# positive pair: (E_510c68b95ca70d, E_563abad5ea5ea1)
# negative pair: (E_510c68b95ca70d, E_8471e062ea771a)
# positive sentences pair: ("brandon industries", "brandon hospitality solutions")
# positive sentences pair: ("brandon industries", "kellogg's factory")
# ================================================================================
# positive pair: (E_b6046e76dd2fe2, E_046d4908b72d47)
# negative pair: (E_b6046e76dd2fe2, E_d72dd3688bf5d9)
# positive sentences pair: ("bandara soekarno hatta terminal 1a", "terminal 1a soekarno hatta")
# positive sentences pair: ("bandara soekarno hatta terminal 1a", "soekarna-hatta international airport")
# ================================================================================
# positive pair: (E_071805c4366bea, E_f1c63449349a03)
# negative pair: (E_071805c4366bea, E_d5f63d48e2c939)
# positive sentences pair: ("17 кабинет", "сибирский лицей")
# positive sentences pair: ("17 кабинет", "кабинет английского на третьем этаже")
# ================================================================================
# positive pair: (E_cda0c0bdb043b2, E_15ea339d83e2a4)
# negative pair: (E_cda0c0bdb043b2, E_ab9be1e469035c)
# positive sentences pair: ("lough rynn castle", "lough rynn")
# positive sentences pair: ("lough rynn castle", "belfast metropolitan college - castlereagh campus")
# ================================================================================
# positive pair: (E_e7ec5030718615, E_18c4c01eb7aa85)
# negative pair: (E_e7ec5030718615, E_77b82412db9e17)
# positive sentences pair: ("action marketing", "action - pesquisa de mercado")
# positive sentences pair: ("action marketing", "conj. dos industriários")
# ================================================================================
# positive pair: (E_628d9544bd9c7d, E_94159a282353fb)
# negative pair: (E_628d9544bd9c7d, E_bba9b50d687a50)
# positive sentences pair: ("مركز صحي رابغ rabegh phc", "مركز صحي رابغ")
# positive sentences pair: ("مركز صحي رابغ rabegh phc", "مركز مطمئنه للتدريب")
# ================================================================================
# positive pair: (E_1fa158bebf5a7f, E_fe7955e9e0a728)
# negative pair: (E_1fa158bebf5a7f, E_1351e2ea4861c8)
# positive sentences pair: ("tapajós center hotel", "tapajos center hotel")
# positive sentences pair: ("tapajós center hotel", "condominio residencial tapajós")
# ================================================================================
# positive pair: (E_f8aa400422c204, E_66d280dffc8df3)
# negative pair: (E_f8aa400422c204, E_a6ad64004e6a64)
# positive sentences pair: ("oasis marigot", "oasis marigot club and villas")
# positive sentences pair: ("oasis marigot", "turtle time beach")
# ================================================================================
# positive pair: (E_313624f167c2f7, E_9d7d8665f73a11)
# negative pair: (E_313624f167c2f7, E_118196fec9dfd8)
# positive sentences pair: ("acquinas university college", "aquinas")
# positive sentences pair: ("acquinas university college", "beet music school")
# ================================================================================
# positive pair: (E_9e64de0c933a13, E_4cc6861ebc414a)
# negative pair: (E_9e64de0c933a13, E_4c66a8357b14bd)
# positive sentences pair: ("офис авиакомпании s 7", "s7 airlines (представительство)")
# positive sentences pair: ("офис авиакомпании s 7", "саяно–шушенская гэс, агрегат №10")
# ================================================================================
# positive pair: (E_6476ceba7db45e, E_a7e6cc54422446)
# negative pair: (E_6476ceba7db45e, E_47a6367684c90c)
# positive sentences pair: ("beira cimba", "campo de futebol beira cimba")
# positive sentences pair: ("beira cimba", "pura fruta")
# ================================================================================
# positive pair: (E_fdda3c3dcacd33, E_a0960271a18e35)
# negative pair: (E_fdda3c3dcacd33, E_817f5b3a549131)
# positive sentences pair: ("bupa dental hobart", "bupa dental")
# positive sentences pair: ("bupa dental hobart", "hamilton townhouse motel")

# %%
len(results_dev_df), results_dev_df.value_counts("matched") / len(results_dev_df)
# Out:
# (1346336, matched
#  0    0.856983
#  1    0.143017
#  dtype: float64)

# %%
results_test_df = make_pair_dataset(preds_test_df, train_test, n_negatives=CFG.N_NEGATIVES, n_to_prune=CFG.N_CLOSEST, monitor_iter=1000)
# Out:
#   0%|          | 0/192401 [00:00<?, ?it/s]
# ================================================================================
# positive pair: (E_df67d07f262621, E_c76a74840909fe)
# negative pair: (E_df67d07f262621, E_a94e5778d0d8aa)
# positive sentences pair: ("proton bunga raya parts service center", "bunga raya part @ service sdn. bhd.")
# positive sentences pair: ("proton bunga raya parts service center", "toyota thonburi center service")
# ================================================================================
# positive pair: (E_5d9fc6a881adb6, E_c6e9014b9d2b86)
# negative pair: (E_5d9fc6a881adb6, E_665ae273badeee)
# positive sentences pair: ("知粥常乐", "知足常乐")
# positive sentences pair: ("知粥常乐", "老豆猪肉粉")
# ================================================================================
# positive pair: (E_50711029ea07ad, E_a9b0d74a25b8b7)
# negative pair: (E_50711029ea07ad, E_3c880ba348ff50)
# positive sentences pair: ("harris resort-cabanna room", "harris resort")
# positive sentences pair: ("harris resort-cabanna room", "renaissance resort & spa room 142")
# ================================================================================
# positive pair: (E_7eedd32c04e901, E_5c11bf1e3fd04f)
# negative pair: (E_7eedd32c04e901, E_c4bdffdc196033)
# positive sentences pair: ("warung bambu pak iyek - makanan laut", "warung kajol")
# positive sentences pair: ("warung bambu pak iyek - makanan laut", "warung kak zee")
# ================================================================================
# positive pair: (E_6bf4d5da5dc93c, E_38dfb0ad65828f)
# negative pair: (E_6bf4d5da5dc93c, E_e010f94b492d6d)
# positive sentences pair: ("malaysia airlines engineering training centre", "engineering training sec bench fitting workshop (avionic)")
# positive sentences pair: ("malaysia airlines engineering training centre", "business centre kuala lumpur convention centre, level 3")
# ================================================================================
# positive pair: (E_b3eb48b53679ad, E_b1dff50cc1e0fb)
# negative pair: (E_b3eb48b53679ad, E_af9ead20280dc3)
# positive sentences pair: ("cathay causeway 1", "cathay cineplex causeway point cinema 1")
# positive sentences pair: ("cathay causeway 1", "hall 4 @ cathay jem")
# ================================================================================
# positive pair: (E_75781f97d4d20d, E_6e18fd5b0c548f)
# negative pair: (E_75781f97d4d20d, E_37ff6d05741355)
# positive sentences pair: ("zilan seafood", "zilan nasi ayam")
# positive sentences pair: ("zilan seafood", "all blue seafood")
# ================================================================================
# positive pair: (E_1c1f590792c15c, E_f0bd78cf21d8c9)
# negative pair: (E_1c1f590792c15c, E_a5c294d72f4116)
# positive sentences pair: ("gedung fakultas teknik universitas samudra", "fakultas teknik universitas samudra")
# positive sentences pair: ("gedung fakultas teknik universitas samudra", "rs universitas andalas")
# ================================================================================
# positive pair: (E_3ebd74473ebc08, E_644ad850412805)
# negative pair: (E_3ebd74473ebc08, E_80d8d2d9ee559d)
# positive sentences pair: ("parkroyal service suites", "parkroyal lionbest")
# positive sentences pair: ("parkroyal service suites", "park avenue suites room 777")
# ================================================================================
# positive pair: (E_954bf81fb294aa, E_179358cbab5df9)
# negative pair: (E_954bf81fb294aa, E_82c61ac26dfd7f)
# positive sentences pair: ("maxims club casino", "maxims club casino_room 8")
# positive sentences pair: ("maxims club casino", "grand club lounge")
# ================================================================================
# positive pair: (E_a021217ff8cb04, E_1f23767af11e49)
# negative pair: (E_a021217ff8cb04, E_d39606664ccf77)
# positive sentences pair: ("ก๋วยเตี๋ยวต้มยำห้าแยก", "ก๋วยเตี๋ยวต้มยำ 5 แยก")
# positive sentences pair: ("ก๋วยเตี๋ยวต้มยำห้าแยก", "ก๋วยเตี๋ยวแกงส้ม")
# ================================================================================
# positive pair: (E_96a3654303b445, E_a7577bbad5022b)
# negative pair: (E_96a3654303b445, E_459ae4097b8bdd)
# positive sentences pair: ("ยิ่งกี่ เป็ดย่างฮ่องกง (yingki roasted duck) 英記香港澆鴨", "ย่ิงก่ี")
# positive sentences pair: ("ยิ่งกี่ เป็ดย่างฮ่องกง (yingki roasted duck) 英記香港澆鴨", "mei heong yuen dessert 味香园")
# ================================================================================
# positive pair: (E_24d05236852378, E_c5eb6e4e8aaf3e)
# negative pair: (E_24d05236852378, E_8198d9b63c2093)
# positive sentences pair: ("วุฒินมสด", "ร้านวุฒินมสด")
# positive sentences pair: ("วุฒินมสด", "ร้านส้มตำนุสราสารคาม")
# ================================================================================
# positive pair: (E_77aca3d0bc8f3a, E_0730d48bc192c8)
# negative pair: (E_77aca3d0bc8f3a, E_4b90336f21a88e)
# positive sentences pair: ("ร้านอิ่มอกอิ่มใจ", "อิ่มอก อิ่มใจ")
# positive sentences pair: ("ร้านอิ่มอกอิ่มใจ", "ข้าวหมูแดงศรีมรกต")
# ================================================================================
# positive pair: (E_982895f6858725, E_47cb40146f295b)
# negative pair: (E_982895f6858725, E_e3b6def02241db)
# positive sentences pair: ("ชีสซ่า", "ชีสซ่า & หอยครก")
# positive sentences pair: ("ชีสซ่า", "โกปี๊")
# ================================================================================
# positive pair: (E_157c35d6f92fe2, E_7ad27d90b25dc0)
# negative pair: (E_157c35d6f92fe2, E_bf6754f5db97ae)
# positive sentences pair: ("ข้าวขาหมูศิริชัย", "ขนมจีนน้ำยาศิริชัย(ตลาดห้วยขวาง)")
# positive sentences pair: ("ข้าวขาหมูศิริชัย", "ลูกชิ้นปลานายเงี๊ยบ")
# ================================================================================
# positive pair: (E_4dae371cd1f411, E_17c83d7de42b6d)
# negative pair: (E_4dae371cd1f411, E_1eb958d70f9cd4)
# positive sentences pair: ("แอ๊ว ท่าพระจันทร์ (eaw tha phra chan)", "แอ๊ว ท่าพระจันทร์")
# positive sentences pair: ("แอ๊ว ท่าพระจันทร์ (eaw tha phra chan)", "ขนมจีน บ้านเจ็ดยอด (baan ched yod)")
# ================================================================================
# positive pair: (E_554b0b65a718a3, E_a152e0ca0bb09c)
# negative pair: (E_554b0b65a718a3, E_ebe4603801bece)
# positive sentences pair: ("ร้านขนมเค้ก เจ้าเอย", ""ร้านขนมเค้ก \"ขนมเจ้าเอย\""")
# positive sentences pair: ("ร้านขนมเค้ก เจ้าเอย", "นนทบุรี ตำแหลก")
# ================================================================================
# positive pair: (E_fd34f3c99ec939, E_4bffe5a49dfb71)
# negative pair: (E_fd34f3c99ec939, E_4cfcb2a6465c6c)
# positive sentences pair: ("ครัวตานอม", "ตานอม")
# positive sentences pair: ("ครัวตานอม", "ปูนิ่มซีฟู้ด")
# ================================================================================
# positive pair: (E_46449d38fdd9c3, E_67cdefa70b0448)
# negative pair: (E_46449d38fdd9c3, E_9db5313ed9a10c)
# positive sentences pair: ("utcc building 4", "building 4, utcc")
# positive sentences pair: ("utcc building 4", "utcc fitness center")
# ================================================================================
# positive pair: (E_69941d02ac2933, E_341bf64045feb8)
# negative pair: (E_69941d02ac2933, E_9658e9b78e95e3)
# positive sentences pair: ("bu โรงอาหาร1", "cafeteria (โรงอาหาร1) | bangkok university")
# positive sentences pair: ("bu โรงอาหาร1", "หัวปลาช่องนนทรี")
# ================================================================================
# positive pair: (E_116976b5740403, E_aec44a59e99e3c)
# negative pair: (E_116976b5740403, E_3e5055f222b129)
# positive sentences pair: ("cutto@carfour sukhaphiban3", "cutto")
# positive sentences pair: ("cutto@carfour sukhaphiban3", "top cut hair & design")
# ================================================================================
# positive pair: (E_3a5fab75d541ab, E_cf478f7d51b70c)
# negative pair: (E_3a5fab75d541ab, E_9c52a3fb843b40)
# positive sentences pair: ("yalova adliyesi", "yalova adalet sarayı")
# positive sentences pair: ("yalova adliyesi", "yalova devlet hastanesı")
# ================================================================================
# positive pair: (E_6fdf00bbedd51a, E_425b8328281df3)
# negative pair: (E_6fdf00bbedd51a, E_97c1f4263ad3b1)
# positive sentences pair: ("futureisnow@erdengida", "futureisnow@aksahın bufe")
# ================================================================================
# positive pair: (E_318f46c1bd36d7, E_48ae111d95b652)
# negative pair: (E_318f46c1bd36d7, E_e24cc887f77d57)
# positive sentences pair: ("koşuyolupet (gülfem hn)", "kosuyolu pet veteriner klinigi")
# positive sentences pair: ("koşuyolupet (gülfem hn)", "koc kutuphanesi")
# ================================================================================
# positive pair: (E_22872d11b70133, E_acf3198577eaae)
# negative pair: (E_22872d11b70133, E_bc02572245d16f)
# positive sentences pair: ("beyazıt türbesi", "yıldırım bayezid han türbesi")
# positive sentences pair: ("beyazıt türbesi", "tarihi beylerbeyi çınaraltı")
# ================================================================================
# positive pair: (E_f813b54bdf52a3, E_40ec10465bfa24)
# negative pair: (E_f813b54bdf52a3, E_08c82e03c89aa8)
# positive sentences pair: ("hakan gayrimenkul", "hakan gayrimenkul&danışmanlık")
# positive sentences pair: ("hakan gayrimenkul", "tekin gayrimenkul i̇nşaat")
# ================================================================================
# positive pair: (E_0b0764f169a791, E_242353e6940ad5)
# negative pair: (E_0b0764f169a791, E_a2f19a881267a1)
# positive sentences pair: ("otağ kebap&pide salonu", "otagi-danıs")
# positive sentences pair: ("otağ kebap&pide salonu", "karacasu pide&kebap")
# ================================================================================
# positive pair: (E_c880147f0bdafa, E_8c28371c4cd822)
# negative pair: (E_c880147f0bdafa, E_e1c2f835472a42)
# positive sentences pair: ("büyük beşevler parkı", "sosyete parkı")
# positive sentences pair: ("büyük beşevler parkı", "bağcılar ebu bekir parki")
# ================================================================================
# positive pair: (E_b47848b04460bf, E_391020e9a9b658)
# negative pair: (E_b47848b04460bf, E_37c0eaf42b3ad3)
# positive sentences pair: ("onur emlak", "emre&onur kuaför")
# positive sentences pair: ("onur emlak", "önder emlak")
# ================================================================================
# positive pair: (E_1bb3eefb10ec35, E_a6ab38b919ae18)
# negative pair: (E_1bb3eefb10ec35, E_62dc78e5c1d0c7)
# positive sentences pair: ("yakacık kurban kesim alanı", "karsiyaka kurban kesim alani")
# positive sentences pair: ("yakacık kurban kesim alanı", "yol sürücü kursu eğitim alanı")
# ================================================================================
# positive pair: (E_fb4eeefd20fd3c, E_4cd0ed06bc7a66)
# negative pair: (E_fb4eeefd20fd3c, E_d2be42f17b29f9)
# positive sentences pair: ("tekel deposu", "üsküdar tekel deposu")
# positive sentences pair: ("tekel deposu", "tei̇aş")
# ================================================================================
# positive pair: (E_c364838ca2ba7a, E_42b7129d29678e)
# negative pair: (E_c364838ca2ba7a, E_37ccc5da8f4a40)
# positive sentences pair: ("tokyo connection ciwalk", "tokyo connection, broadway ciwalk")
# positive sentences pair: ("tokyo connection ciwalk", "jakarta international expo(jiexpo )")
# ================================================================================
# positive pair: (E_c4d792140b8e8f, E_aa15f9f04f8294)
# negative pair: (E_c4d792140b8e8f, E_31d136dc334eaf)
# positive sentences pair: ("rs puri cinere room 463", "ruang melati 515 hospital cinere")
# positive sentences pair: ("rs puri cinere room 463", "topaz 7 room, rsia permata cibubur")
# ================================================================================
# positive pair: (E_0541263b250089, E_451cab99ec262c)
# negative pair: (E_0541263b250089, E_3e0125bcbc3186)
# positive sentences pair: ("ruang c3 fkip unila", "fakultas keguruan & ilmu pendidikan")
# positive sentences pair: ("ruang c3 fkip unila", "ruang 3.16 gkb 3 unmuh")
# ================================================================================
# positive pair: (E_e25931cc98d52c, E_756f202588f3b4)
# negative pair: (E_e25931cc98d52c, E_d4c9ebfdc7c30f)
# positive sentences pair: ("x-7 icons class", "lab komputer smam 1 tsm")
# positive sentences pair: ("x-7 icons class", "x-6 sman 21 jakarta")
# ================================================================================
# positive pair: (E_a32cb56b4571e4, E_9c8fca768db6e5)
# negative pair: (E_a32cb56b4571e4, E_4f8255fad8b326)
# positive sentences pair: ("center stage - novotel lampung", "center stage novotel")
# positive sentences pair: ("center stage - novotel lampung", "man 1 model bandar lampung")
# ================================================================================
# positive pair: (E_f8f52dae0c36e1, E_723c8661f9a528)
# negative pair: (E_f8f52dae0c36e1, E_1d8739835e620e)
# positive sentences pair: ("bandara halim", "halim perdanakusuma international airport")
# positive sentences pair: ("bandara halim", "bandara ngurah rai (dps)")
# ================================================================================
# positive pair: (E_92efeee7596508, E_6ebe5475b7d49d)
# negative pair: (E_92efeee7596508, E_217cdcb6759ccb)
# positive sentences pair: ("r. doa sekolah bunda mulia", "sekolah bunda mulia")
# positive sentences pair: ("r. doa sekolah bunda mulia", "sekolah tinggi bahasa asing")
# ================================================================================
# positive pair: (E_1cce6e3882b7d6, E_8efba0f627eba7)
# negative pair: (E_1cce6e3882b7d6, E_6a383a2dcccbb3)
# positive sentences pair: ("karinda caffe & resto metro permata i", "karinda café & resto")
# positive sentences pair: ("karinda caffe & resto metro permata i", "permata mediterania")
# ================================================================================
# positive pair: (E_c00377de78674d, E_e880dfc306ba3e)
# negative pair: (E_c00377de78674d, E_65d7274d579d76)
# positive sentences pair: ("x.o suki harapan indah bekasi", "x.o suki & cuisine - harapan indah")
# positive sentences pair: ("x.o suki harapan indah bekasi", "harapan indah")
# ================================================================================
# positive pair: (E_7b6de1b3fe8a55, E_5b090ad953640e)
# negative pair: (E_7b6de1b3fe8a55, E_de5ced8e89a99d)
# positive sentences pair: ("ruang anggrek hospital cinere", "kamar mawar 527a puri cinere hospital")
# positive sentences pair: ("ruang anggrek hospital cinere", "angkringan terang bulan")
# ================================================================================
# positive pair: (E_4db18d04a58f16, E_85a214c09798c6)
# negative pair: (E_4db18d04a58f16, E_536335141a4cd9)
# positive sentences pair: ("ミスタードーナツ南林間駅", "ミスタードーナツ 南林間駅前ショップ")
# positive sentences pair: ("ミスタードーナツ南林間駅", "イオンバイク 港北センター店")
# ================================================================================
# positive pair: (E_ae65f721efae8f, E_b3f2b5fdda9206)
# negative pair: (E_ae65f721efae8f, E_505278551a710b)
# positive sentences pair: ("横浜市立神奈川中学校 コミュニティハウス", "横浜市立神奈川中学校")
# positive sentences pair: ("横浜市立神奈川中学校 コミュニティハウス", "神奈川工科大学 d2号館")
# ================================================================================
# positive pair: (E_77800801101675, E_36f9140d402053)
# negative pair: (E_77800801101675, E_f22e20516b510a)
# positive sentences pair: ("お食事処 みはらし", "みはらし")
# positive sentences pair: ("お食事処 みはらし", "食品館あおば")
# ================================================================================
# positive pair: (E_832311a11166d8, E_2ae4de5fbaac6b)
# negative pair: (E_832311a11166d8, E_046c2e77b830d6)
# positive sentences pair: ("らーめん愉悦処 鏡花", "ラーメン鏡花")
# positive sentences pair: ("らーめん愉悦処 鏡花", "浪花 古市庵・越後屋甚兵衛 フードショー店")
# ================================================================================
# positive pair: (E_5009a9a54bf959, E_f88166bd09cfe7)
# negative pair: (E_5009a9a54bf959, E_a0921cc5b9f79c)
# positive sentences pair: ("タイ式マッサージ ティチャバー", "タイ料理 ティーチャバ")
# positive sentences pair: ("タイ式マッサージ ティチャバー", "カオマンガイ バザール 三鷹")
# ================================================================================
# positive pair: (E_c0ecf2a1d30c7c, E_0ad407a20ae9a5)
# negative pair: (E_c0ecf2a1d30c7c, E_b9c24cfdc17bf9)
# positive sentences pair: ("ココカラファイン薬局 仙川店", "ココカラファイン 仙川店")
# positive sentences pair: ("ココカラファイン薬局 仙川店", "ココカラファイン ジップドラッグ久米店")
# ================================================================================
# positive pair: (E_2e7b32b2788397, E_a2e26151b1fa46)
# negative pair: (E_2e7b32b2788397, E_c71ef6fb31627a)
# positive sentences pair: ("オラウータン", "オランウータン")
# positive sentences pair: ("オラウータン", "イースター・イン・ニューヨーク")
# ================================================================================
# positive pair: (E_3460398037befe, E_4abd7b961af0ac)
# negative pair: (E_3460398037befe, E_5530f1870a24ba)
# positive sentences pair: ("世田谷区役所", "世田谷区役所 (setagaya city hall)")
# positive sentences pair: ("世田谷区役所", "吉田医院 小児科 皮膚科")
# ================================================================================
# positive pair: (E_1ec8ecaa68a642, E_ed2140999413de)
# negative pair: (E_1ec8ecaa68a642, E_e49519f220de6b)
# positive sentences pair: ("farys magazijn", "farys")
# positive sentences pair: ("farys magazijn", "the rizty")
# ================================================================================
# positive pair: (E_1a40ba40af06be, E_21a9721143726e)
# negative pair: (E_1a40ba40af06be, E_30c64e8bb43efd)
# positive sentences pair: ("veilinghuis vavato", "vavato")
# positive sentences pair: ("veilinghuis vavato", "stadhuis aalter")
# ================================================================================
# positive pair: (E_54b90396bf7d5f, E_1a72eab736593b)
# negative pair: (E_54b90396bf7d5f, E_e93afaa81ee907)
# positive sentences pair: ("begraafplaats mollen", "kerkhof mollem")
# positive sentences pair: ("begraafplaats mollen", "novotel brüksel")
# ================================================================================
# positive pair: (E_36b1961445d273, E_dae338a8797e1d)
# negative pair: (E_36b1961445d273, E_78fc422f27226b)
# positive sentences pair: ("houslow central", "london underground")
# positive sentences pair: ("houslow central", "holborn london underground")
# ================================================================================
# positive pair: (E_054132b57f7ade, E_993351eff79eb2)
# negative pair: (E_054132b57f7ade, E_dad8344d62bdd3)
# positive sentences pair: ("winchester city mill", "winchester city mill museum")
# positive sentences pair: ("winchester city mill", "wolverhampton st george's metro station")
# ================================================================================
# positive pair: (E_e2f3c938bfeeab, E_d2b36aa889a964)
# negative pair: (E_e2f3c938bfeeab, E_a25624e6f541af)
# positive sentences pair: ("vomar voordeelmarkt schagen", "vomar laagzijde schagen")
# positive sentences pair: ("vomar voordeelmarkt schagen", "de voorplekke")
# ================================================================================
# positive pair: (E_012cc2a9e0093e, E_3463a45d2de64b)
# negative pair: (E_012cc2a9e0093e, E_b4bb06fbfca5f5)
# positive sentences pair: ("cgg de drie stromen", "ccg drie stromen lokeren")
# positive sentences pair: ("cgg de drie stromen", "stal 't vossenhol")
# ================================================================================
# positive pair: (E_2aa07c762dd2f4, E_bc6dd81a92d8ac)
# negative pair: (E_2aa07c762dd2f4, E_0e809d864a6407)
# positive sentences pair: ("hakan doğan saç tasarım", "hakan doğan imagemaker")
# positive sentences pair: ("hakan doğan saç tasarım", "makkas erkek saç tasarımı")
# ================================================================================
# positive pair: (E_5eb40031300eb2, E_18f868779da41b)
# negative pair: (E_5eb40031300eb2, E_3500d32325ecff)
# positive sentences pair: ("key kuaför", "key kuaför ve güzellik salonu")
# positive sentences pair: ("key kuaför", "tuncer kuaför")
# ================================================================================
# positive pair: (E_f98ecc64c2734d, E_8cf2047ee51005)
# negative pair: (E_f98ecc64c2734d, E_8e1cc365993ab0)
# positive sentences pair: ("uluborlu toki e1", "uluborlu toki")
# positive sentences pair: ("uluborlu toki e1", "beykent toki 1. etap")
# ================================================================================
# positive pair: (E_c7e610999a3cba, E_997177332e3b89)
# negative pair: (E_c7e610999a3cba, E_5aa39a3327f282)
# positive sentences pair: ("hermes otel", "otel hermes kaş")
# positive sentences pair: ("hermes otel", "swiss otel")
# ================================================================================
# positive pair: (E_2473e52fc9282c, E_ca6104a0090485)
# negative pair: (E_2473e52fc9282c, E_25daa26bae2555)
# positive sentences pair: ("çilek pastanesi", "çilek boutique patisserie")
# positive sentences pair: ("çilek pastanesi", "liva pastanesi")
# ================================================================================
# positive pair: (E_0cfe56c7e8e38e, E_68a72b3eadbefd)
# negative pair: (E_0cfe56c7e8e38e, E_3ee35b762fd073)
# positive sentences pair: ("sdü koç fest alani", "koç fest sdü")
# positive sentences pair: ("sdü koç fest alani", "sdr dance academy")
# ================================================================================
# positive pair: (E_4d450afcad7eaa, E_b46f2f2be151f8)
# negative pair: (E_4d450afcad7eaa, E_9ae389e05a7894)
# positive sentences pair: ("744 foca hatundere", "744 eski foça-hatundere aktarma")
# positive sentences pair: ("744 foca hatundere", "foça sahili")
# ================================================================================
# positive pair: (E_bffd37ce46745c, E_df6c62fdcb74a1)
# negative pair: (E_bffd37ce46745c, E_1e317c29a6dc23)
# positive sentences pair: ("gunung simping permai", "perum gunung simping permai (gsp)")
# positive sentences pair: ("gunung simping permai", "gunung tangkuban perahu")
# ================================================================================
# positive pair: (E_38cc0cda8a0987, E_e4958792caa7c3)
# negative pair: (E_38cc0cda8a0987, E_5174da9ffe5d4e)
# positive sentences pair: ("pasar sukawati", "pasar sukawati galianyar, bali")
# positive sentences pair: ("pasar sukawati", "gelora susi susanti")
# ================================================================================
# positive pair: (E_3a2d82f87731f7, E_6c825ba563db80)
# negative pair: (E_3a2d82f87731f7, E_16b38a90bda473)
# positive sentences pair: ("kantor pelni surabaya", "graha pelni")
# positive sentences pair: ("kantor pelni surabaya", "kantor pemkab probolinggo")
# ================================================================================
# positive pair: (E_0e6874fe2aa49d, E_8b0d07c7354613)
# negative pair: (E_0e6874fe2aa49d, E_a546dc91413625)
# positive sentences pair: ("foodcourt basement 1 galeria mall", "foodcourt basement 1")
# positive sentences pair: ("foodcourt basement 1 galeria mall", "foodcourt blok m mall")
# ================================================================================
# positive pair: (E_f7944aaa78294a, E_7efccea8befbf8)
# negative pair: (E_f7944aaa78294a, E_e89252aadf1aab)
# positive sentences pair: ("rocky warung", "rocky warung bar and grill")
# positive sentences pair: ("rocky warung", "rocky ( royal kid,s church )")
# ================================================================================
# positive pair: (E_0130c90748c65b, E_a9c3738571b476)
# negative pair: (E_0130c90748c65b, E_d5e56efffa18ce)
# positive sentences pair: ("ajbs home improvement center", "ajbs jenggolo, sda")
# positive sentences pair: ("ajbs home improvement center", "lion air training center (ltc)")
# ================================================================================
# positive pair: (E_a470925998b304, E_542955dfc4a1b0)
# negative pair: (E_a470925998b304, E_e3423b303eba10)
# positive sentences pair: ("pasar kranggan jl. diponegoro", "pasar kranggan")
# positive sentences pair: ("pasar kranggan jl. diponegoro", "depan patung soekarno-hatta")
# ================================================================================
# positive pair: (E_89391c3d025d74, E_8db1ebaabacccd)
# negative pair: (E_89391c3d025d74, E_772497a28d7129)
# positive sentences pair: ("plamenac", "vila „plamenac”")
# positive sentences pair: ("plamenac", "carpediem plastion")
# ================================================================================
# positive pair: (E_8c0573531b4717, E_f2e1a2408d39e7)
# negative pair: (E_8c0573531b4717, E_0c26c4d4379497)
# positive sentences pair: ("cemal kamaci spor kopleksi", "cemal kamacı spor kompleksi")
# positive sentences pair: ("cemal kamaci spor kopleksi", "küçükçekmece sahili")
# ================================================================================
# positive pair: (E_bbb08b79e26723, E_5a62b73e71f9a2)
# negative pair: (E_bbb08b79e26723, E_c35c2cf1c86b37)
# positive sentences pair: ("aras çanta", "aras promosyon çanta i̇malatçısı")
# positive sentences pair: ("aras çanta", "aras cafe & restaurant")
# ================================================================================
# positive pair: (E_c36a7e1cff61d3, E_20aea6e6c64399)
# negative pair: (E_c36a7e1cff61d3, E_87af02485cb3ed)
# positive sentences pair: ("aybars-ak orta okulu", "basınkoy aybars ak ortaokulu")
# positive sentences pair: ("aybars-ak orta okulu", "ordu çarşı")
# ================================================================================
# positive pair: (E_54019a9ccddcdb, E_6160907700b603)
# negative pair: (E_54019a9ccddcdb, E_6ad9d9266ae97c)
# positive sentences pair: ("uludag universitesi tip fakultesi yemekhanesi", "uludag unıversıtesı tıp fakultesı")
# positive sentences pair: ("uludag universitesi tip fakultesi yemekhanesi", "muğla üniversitesi eğitim fakültesi")
# ================================================================================
# positive pair: (E_51909a9136b183, E_c7a5e85fd2a4a3)
# negative pair: (E_51909a9136b183, E_cda39f26d834ab)
# positive sentences pair: ("borusan asım kocabıyık mtal spor salonu", "borusan asım kocabıyık anadolu meslek lisesi spor salonu")
# positive sentences pair: ("borusan asım kocabıyık mtal spor salonu", "bor seker fabrikası toplantı salonu")
# ================================================================================
# positive pair: (E_e7f7341d85fca0, E_e150b7afa8d70b)
# negative pair: (E_e7f7341d85fca0, E_635a4ecb18776d)
# positive sentences pair: ("jos. schneider optische werke gmbh bad kreuznach", "schneider kreuznach optische werke")
# positive sentences pair: ("jos. schneider optische werke gmbh bad kreuznach", "schleiff denkmalentwicklung gmbh")
# ================================================================================
# positive pair: (E_05e61d935aef3c, E_ce4fce22a07902)
# negative pair: (E_05e61d935aef3c, E_96212f2c885694)
# positive sentences pair: ("ferrero mod.", "ferrero s.p.a")
# positive sentences pair: ("ferrero mod.", "aalter paint")
# ================================================================================
# positive pair: (E_8f08b73117c604, E_9e711c29f60123)
# negative pair: (E_8f08b73117c604, E_1675cae2587a0d)
# positive sentences pair: ("modern toerisme van riet", "modern toerisme")
# positive sentences pair: ("modern toerisme van riet", "tandarts ann vantieghem")
# ================================================================================
# positive pair: (E_ae7a19e4ea3b79, E_962d61c657b6d4)
# negative pair: (E_ae7a19e4ea3b79, E_33580437b461f4)
# positive sentences pair: ("u+h maximilianstraße", "u-bahnhof maximilianstr.")
# positive sentences pair: ("u+h maximilianstraße", "u+h hauptbahnhof")
# ================================================================================
# positive pair: (E_d43eaf3a2f21e4, E_18d84085d2e799)
# negative pair: (E_d43eaf3a2f21e4, E_bc7e480c0baea4)
# positive sentences pair: ("radstation zollhafen", "radstation nahestraße / zollhafen")
# positive sentences pair: ("radstation zollhafen", "nachtskilaufen rreiterkogel")
# ================================================================================
# positive pair: (E_d1a9b8b59042b4, E_6bdc6d0ac186c3)
# negative pair: (E_d1a9b8b59042b4, E_9c80fd966d18ed)
# positive sentences pair: ("dwd immobilien gmbh", "dwd immobilien gmbh hausverkauf ratingen")
# positive sentences pair: ("dwd immobilien gmbh", "vks immobilier")
# ================================================================================
# positive pair: (E_eed8198752825a, E_fe0fe5a363c173)
# negative pair: (E_eed8198752825a, E_9aa522a056449d)
# positive sentences pair: ("кафедра интегрированных коммуникаций вшэ", "факультет коммуникаций, медиа и дизайна вшэ")
# positive sentences pair: ("кафедра интегрированных коммуникаций вшэ", "кабинет софии яковлены")
# ================================================================================
# positive pair: (E_00a6ffc5b1b303, E_9ad90d2ddb6f36)
# negative pair: (E_00a6ffc5b1b303, E_3af2ee4ee1e6ac)
# positive sentences pair: ("столовая аграрный", "столовая аграрного")
# positive sentences pair: ("столовая аграрный", "автогровер")
# ================================================================================
# positive pair: (E_0166e383c4b2ab, E_00a065949b0b32)
# negative pair: (E_0166e383c4b2ab, E_8cd0da52228412)
# positive sentences pair: ("disco 90", "диско бар 90-х")
# positive sentences pair: ("disco 90", "swagger dance studio")
# ================================================================================
# positive pair: (E_45fa3fd0a91c7e, E_83dc636a313ace)
# negative pair: (E_45fa3fd0a91c7e, E_61241d6f74e333)
# positive sentences pair: ("московский киновидеоинститут", "мкви")
# positive sentences pair: ("московский киновидеоинститут", "российский университет дружбы народов (рудн)")
# ================================================================================
# positive pair: (E_c9948d5883adb4, E_7cfc8ce0d75334)
# negative pair: (E_c9948d5883adb4, E_27dad74b3f5cd9)
# positive sentences pair: ("ул саморы-машела д.4 к.3", "саморы машела, 4к3")
# positive sentences pair: ("ул саморы-машела д.4 к.3", "ул. михаила дудина, 25, корп. 1")
# ================================================================================
# positive pair: (E_aae1d768c20319, E_c3c58b87f6f0c1)
# negative pair: (E_aae1d768c20319, E_d447ba0a1eeb8a)
# positive sentences pair: ("bolsa", "ボルサ 津島店(bolsa)")
# positive sentences pair: ("bolsa", "la boucherie omi")
# ================================================================================
# positive pair: (E_ac4d36906952aa, E_07ef8b89dfac1d)
# negative pair: (E_ac4d36906952aa, E_5f157940524a6a)
# positive sentences pair: ("はらっば", "スパゲッティ専科はらっぱ モントレー店")
# positive sentences pair: ("はらっば", "若菜そば")
# ================================================================================
# positive pair: (E_134dd14c582887, E_54ff4b280f0bb0)
# negative pair: (E_134dd14c582887, E_a424b0e9b846f9)
# positive sentences pair: ("大津駅 1-2番線ホーム 待合室", "1-2番線ホーム 待合室")
# positive sentences pair: ("大津駅 1-2番線ホーム 待合室", "5-6番線ホーム喫煙所")
# ================================================================================
# positive pair: (E_b2f70a85778224, E_7dc7f9ed1bbc26)
# negative pair: (E_b2f70a85778224, E_64950b5c5612f4)
# positive sentences pair: ("hub 梅田茶屋町店", "ｈｕｂ ～ハブ～ 梅田茶屋町店")
# positive sentences pair: ("hub 梅田茶屋町店", "眼科 杉田病院")
# ================================================================================
# positive pair: (E_5113828adcdb25, E_463b88a38efc8c)
# negative pair: (E_5113828adcdb25, E_aedec56912f7f5)
# positive sentences pair: ("株式会社デンソー技研センター", "デンソー 大府技術研究所")
# positive sentences pair: ("株式会社デンソー技研センター", "株式会社kddiウェブコミュニケーションズ")
# ================================================================================
# positive pair: (E_dc937582120fae, E_fd17ebb8d9aff6)
# negative pair: (E_dc937582120fae, E_76295ab28ab0e4)
# positive sentences pair: ("天下一品 太秦店 (tenkaippin)", "天下一品 三条うずまさ店")
# positive sentences pair: ("天下一品 太秦店 (tenkaippin)", "天下一番保戸野総本店")
# ================================================================================
# positive pair: (E_94c6881b924817, E_e574af355f5d7c)
# negative pair: (E_94c6881b924817, E_fa18bd58c8e84b)
# positive sentences pair: ("마세라티(maserati) 분당전시장", "마세라티 분당전시장")
# positive sentences pair: ("마세라티(maserati) 분당전시장", "동강한우타운정육점")
# ================================================================================
# positive pair: (E_60860303ace511, E_30d26af46307a1)
# negative pair: (E_60860303ace511, E_230bbc0849ebce)
# positive sentences pair: ("saint augustin", "생어거스틴 / saint augustin")
# positive sentences pair: ("saint augustin", "aimei at le royal meridien")
# ================================================================================
# positive pair: (E_0548202d847a40, E_3d20167e16d400)
# negative pair: (E_0548202d847a40, E_185fca9c6789be)
# positive sentences pair: ("이화수", "이화수전통육개장")
# positive sentences pair: ("이화수", "안성한우")
# ================================================================================
# positive pair: (E_8b6917ee1973bc, E_0d0ade029f365e)
# negative pair: (E_8b6917ee1973bc, E_eda621ae0e70d4)
# positive sentences pair: ("김치찌개집", "간판없는 김치찌개집")
# positive sentences pair: ("김치찌개집", "가든세계평화")
# ================================================================================
# positive pair: (E_d7d378a801b702, E_7d81c6f18792db)
# negative pair: (E_d7d378a801b702, E_a1a16ebb3d485a)
# positive sentences pair: ("frederick marc station", "transit station")
# positive sentences pair: ("frederick marc station", "tomah amtrak station")
# ================================================================================
# positive pair: (E_b732cbf2a77e4d, E_16917419e78bac)
# negative pair: (E_b732cbf2a77e4d, E_d1d3aa936da147)
# positive sentences pair: ("super kings chinese buffet", "super kings buffet")
# positive sentences pair: ("super kings chinese buffet", "joann buffet")
# ================================================================================
# positive pair: (E_6cfa28705844b8, E_d447464ee7deb7)
# negative pair: (E_6cfa28705844b8, E_5f510ef77e8efa)
# positive sentences pair: ("grace wenjun guo, md", "charles d. vinocur, md")
# positive sentences pair: ("grace wenjun guo, md", "george william till, md")
# ================================================================================
# positive pair: (E_fda30c2f66de16, E_1d971a83855c6a)
# negative pair: (E_fda30c2f66de16, E_9fe6b9f49bc736)
# positive sentences pair: ("rest area 8-36 (southbound)", "rest area 8-36 vending")
# positive sentences pair: ("rest area 8-36 (southbound)", "northbound rest area")
# ================================================================================
# positive pair: (E_ff0c4cf777f2b8, E_d487de8b70a995)
# negative pair: (E_ff0c4cf777f2b8, E_3d36703695b008)
# positive sentences pair: ("nationwide insurance agent chad matthew lewis", "nationwide insurance: chad matthew lewis")
# positive sentences pair: ("nationwide insurance agent chad matthew lewis", "nationwide insurance - bryan slater agency")
# ================================================================================
# positive pair: (E_0696111fbe8d75, E_e039836719ae72)
# negative pair: (E_0696111fbe8d75, E_6aad2740740f92)
# positive sentences pair: ("tbg theatre", "the barrow group")
# positive sentences pair: ("tbg theatre", "walnut street theatre")
# ================================================================================
# positive pair: (E_f87e66e4e8ff69, E_3140afeece9ee0)
# negative pair: (E_f87e66e4e8ff69, E_6ed3f933d9a776)
# positive sentences pair: ("p.s. 250", "ps 250")
# positive sentences pair: ("p.s. 250", "vfw 2520")
# ================================================================================
# positive pair: (E_a6464e43e9a218, E_e9263f2f86df8f)
# negative pair: (E_a6464e43e9a218, E_0eb6285047d08b)
# positive sentences pair: ("samuels sinclair dental center", "samuel dental clinic")
# positive sentences pair: ("samuels sinclair dental center", "dental village associates")
# ================================================================================
# positive pair: (E_7877f581cdd4d9, E_95db6c438c74ec)
# negative pair: (E_7877f581cdd4d9, E_6488bb32437c89)
# positive sentences pair: ("merck blg 800 rahway, nj", "merck & co., inc. - rahway campus")
# positive sentences pair: ("merck blg 800 rahway, nj", "hhs-boulevard")
# ================================================================================
# positive pair: (E_77b09e1262d7d4, E_4013e31e179cc8)
# negative pair: (E_77b09e1262d7d4, E_91dda0bd5d5c87)
# positive sentences pair: ("töölön torikahvila", "töölöntorin kahvila")
# positive sentences pair: ("töölön torikahvila", "talin liikuntapuisto")
# ================================================================================
# positive pair: (E_d6e9bc85bfa317, E_8c7ae6ae9fb4d0)
# negative pair: (E_d6e9bc85bfa317, E_ffd2685b3822a1)
# positive sentences pair: ("park food job", "park food")
# positive sentences pair: ("park food job", "shen park")
# ================================================================================
# positive pair: (E_12826e2d107b2d, E_d49fc3d6ab2330)
# negative pair: (E_12826e2d107b2d, E_075b117c90b2c1)
# positive sentences pair: ("5озёр", "трк «5 озёр»")
# positive sentences pair: ("5озёр", "зал 5 (синема парк )")
# ================================================================================
# positive pair: (E_2b29b46bd19b2f, E_199a30ffc61773)
# negative pair: (E_2b29b46bd19b2f, E_d54e53e6688233)
# positive sentences pair: (""остановка \"беринга\""", "остановка «малый просп. в. о., 70»")
# positive sentences pair: (""остановка \"беринга\""", ""остановка \"проспект науки\""")
# ================================================================================
# positive pair: (E_9b919cd22a97e5, E_9e5e0db9f90f26)
# negative pair: (E_9b919cd22a97e5, E_1683fbdfca16e9)
# positive sentences pair: ("ราเมน(นะ)ยะ", "ราเมน-ยะ")
# positive sentences pair: ("ราเมน(นะ)ยะ", "ร้านนก-อาหารตามสั่ง")
# ================================================================================
# positive pair: (E_6bb6601debbfa0, E_f8245b7777f7a9)
# negative pair: (E_6bb6601debbfa0, E_779ef0af3f0211)
# positive sentences pair: ("นายแกะ", "ร้านอาหารนายแกะ อ.มหาราช")
# positive sentences pair: ("นายแกะ", "ตาปี")
# ================================================================================
# positive pair: (E_b3b5973df2bcbb, E_7a0bc929ec2321)
# negative pair: (E_b3b5973df2bcbb, E_8460fb92e8290b)
# positive sentences pair: ("โรงแรมขวัญมอ", "โรงแรมขวัญมอ (kwan mor hotel)")
# positive sentences pair: ("โรงแรมขวัญมอ", "โรงแรมกานมณีพาเลส")
# ================================================================================
# positive pair: (E_cc58c05479873d, E_3e386587066afb)
# negative pair: (E_cc58c05479873d, E_ff69dc588158cb)
# positive sentences pair: ("liechtenstein palace", "lichtenštejnský palác")
# positive sentences pair: ("liechtenstein palace", "chen's palace")
# ================================================================================
# positive pair: (E_06887bc44c84bf, E_4779b62aa8adb1)
# negative pair: (E_06887bc44c84bf, E_ccf2e214dcab8c)
# positive sentences pair: ("dětské hřiště nám. jiřího z poděbrad", "hristatko")
# positive sentences pair: ("dětské hřiště nám. jiřího z poděbrad", "dětské hřiště hrdlořezy")
# ================================================================================
# positive pair: (E_bdb04368dc9b96, E_867dd927e41517)
# negative pair: (E_bdb04368dc9b96, E_0ce9a1b466f52e)
# positive sentences pair: ("oddys greenbelt", "oody's")
# positive sentences pair: ("oddys greenbelt", "lifefitness greenbelt 5")
# ================================================================================
# positive pair: (E_74122b4019769d, E_e8334a38452229)
# negative pair: (E_74122b4019769d, E_ee6b35ec02eab6)
# positive sentences pair: ("cocohills", "coco hills compound")
# positive sentences pair: ("cocohills", "bpi north greenhills")
# ================================================================================
# positive pair: (E_0c723eba071b9e, E_78df1a750dd893)
# negative pair: (E_0c723eba071b9e, E_952dcc7adea42b)
# positive sentences pair: ("coffee blends", "coffee blends (los baños, laguna)")
# positive sentences pair: ("coffee blends", "starbucks science hub 3")
# ================================================================================
# positive pair: (E_606f78921072f3, E_68be57a8cdfc11)
# negative pair: (E_606f78921072f3, E_f06c70cd9005e0)
# positive sentences pair: ("advantage spa & pool repair", "advantage pool and spa repair")
# positive sentences pair: ("advantage spa & pool repair", "foxtail pool club")
# ================================================================================
# positive pair: (E_7a7a70b352b1d6, E_b9e623f55624be)
# negative pair: (E_7a7a70b352b1d6, E_c2a07d18a402b4)
# positive sentences pair: ("james c. enochs high school", "ms. adair")
# positive sentences pair: ("james c. enochs high school", "ernie pyle elementary school")
# ================================================================================
# positive pair: (E_8a3004af9eb188, E_0d908b6cf2e9d9)
# negative pair: (E_8a3004af9eb188, E_3e50f408d78f6b)
# positive sentences pair: ("lattc - a building", "lattc - j building")
# positive sentences pair: ("lattc - a building", "lmu - hilton center")
# ================================================================================
# positive pair: (E_2a73bf38323a5e, E_d925ecf85eddfc)
# negative pair: (E_2a73bf38323a5e, E_ee8d49a76697a0)
# positive sentences pair: ("tortas locas hipocampo", "tortas hipocampo")
# positive sentences pair: ("tortas locas hipocampo", "tortas ahogadas la picosa")
# ================================================================================
# positive pair: (E_5028b94c6e702c, E_d2ed043777a8ff)
# negative pair: (E_5028b94c6e702c, E_bec0bd680f1ca8)
# positive sentences pair: ("daichi teppan & steakhouse", "daichi teppan & steakhouse plaza chapultepec")
# positive sentences pair: ("daichi teppan & steakhouse", "shogun japanese steak house")
# ================================================================================
# positive pair: (E_d501d0ddb217e6, E_28ccd3a76c76f1)
# negative pair: (E_d501d0ddb217e6, E_e7c66390cfaa65)
# positive sentences pair: ("engwall florist & gifts", "engwalls florist")
# positive sentences pair: ("engwall florist & gifts", "floral array and gifts")
# ================================================================================
# positive pair: (E_0a995b355870c0, E_8756b8b8fd76d7)
# negative pair: (E_0a995b355870c0, E_e0d21b5404b6bc)
# positive sentences pair: ("gurley-leep motor werks", "gurly leep motorwerks")
# positive sentences pair: ("gurley-leep motor werks", "barrington motors sales rv")
# ================================================================================
# positive pair: (E_c274c0166d009d, E_98eefd36cfb6ea)
# negative pair: (E_c274c0166d009d, E_a82960e152bbca)
# positive sentences pair: ("long lake recreation area campground", "our very own little camp site")
# positive sentences pair: ("long lake recreation area campground", "lakefront trail")
# ================================================================================
# positive pair: (E_da8de949e6d3cf, E_6c61ae41a11689)
# negative pair: (E_da8de949e6d3cf, E_ad630121ce050e)
# positive sentences pair: ("clothes 16", "clothes 46")
# positive sentences pair: ("clothes 16", "clothes15")
# ================================================================================
# positive pair: (E_653c59736cb76a, E_e31bd7ed0be611)
# negative pair: (E_653c59736cb76a, E_c904f0bd3ae7f1)
# positive sentences pair: ("j. crayton pruitt biomedical engineering building", "biomedical sciences building at uf")
# positive sentences pair: ("j. crayton pruitt biomedical engineering building", "stetson medical building")
# ================================================================================
# positive pair: (E_3e47a36dc487ed, E_6f070db751227d)
# negative pair: (E_3e47a36dc487ed, E_147b74b6d0d736)
# positive sentences pair: ("kum mahallesi plajı", "kum mahallesi beach")
# positive sentences pair: ("kum mahallesi plajı", "kumluk plajı")
# ================================================================================
# positive pair: (E_efa0a853e9fdae, E_b1e385af746f81)
# negative pair: (E_efa0a853e9fdae, E_32a178c5dea497)
# positive sentences pair: ("sultanahmet köftecisi palm city avm", "palm city sultanahmet")
# positive sentences pair: ("sultanahmet köftecisi palm city avm", "mardan palace lojman")
# ================================================================================
# positive pair: (E_407b4791896786, E_40f82791cae4fd)
# negative pair: (E_407b4791896786, E_fe4aa3927bf9da)
# positive sentences pair: ("sash the quality coffee", "sash coffee")
# positive sentences pair: ("sash the quality coffee", "brew mood coffee & tea")
# ================================================================================
# positive pair: (E_57d1e325975c4a, E_88aec31b401f39)
# negative pair: (E_57d1e325975c4a, E_c76c664e8126e7)
# positive sentences pair: ("رستوران زاگرس | zagros restaurant", "کافه رستوران زاگرس- بند")
# positive sentences pair: ("رستوران زاگرس | zagros restaurant", "rama cafe restaurant | کافه رستوران راما")
# ================================================================================
# positive pair: (E_8fdf359ce1efe8, E_ed1a4c72f05d9e)
# negative pair: (E_8fdf359ce1efe8, E_1b9e8becde21a3)
# positive sentences pair: ("growler usa - tulsa hills", "growler usa - america's microbrew pub")
# positive sentences pair: ("growler usa - tulsa hills", "tulsa hyundai")
# ================================================================================
# positive pair: (E_5a165d2895064b, E_79fbe3c74671bb)
# negative pair: (E_5a165d2895064b, E_b1bf6a7c5f520b)
# positive sentences pair: ("northwest cardiology", "northwest cardiology - fayetteville")
# positive sentences pair: ("northwest cardiology", "health core physicians group")
# ================================================================================
# positive pair: (E_3bf0a098734b3d, E_4e1355d9148d99)
# negative pair: (E_3bf0a098734b3d, E_8df41f375d11df)
# positive sentences pair: ("b & d skating rink", "b & d skate")
# positive sentences pair: ("b & d skating rink", "brunswick skatestation")
# ================================================================================
# positive pair: (E_6be91fae49b454, E_fa9fa199db6fd7)
# negative pair: (E_6be91fae49b454, E_54b7d4ec5bb00c)
# positive sentences pair: ("cooper systems, inc.", "cooper systems")
# positive sentences pair: ("cooper systems, inc.", "auto technical, inc.")
# ================================================================================
# positive pair: (E_7f107875ff7197, E_2027b13d0cc0f4)
# negative pair: (E_7f107875ff7197, E_b3acc3a173da40)
# positive sentences pair: ("x-ploud gym", "x-plan gym")
# positive sentences pair: ("x-ploud gym", "academia body fit club")
# ================================================================================
# positive pair: (E_ab3255ddd7c6ee, E_cf14ece212731a)
# negative pair: (E_ab3255ddd7c6ee, E_c83b7316aa4d25)
# positive sentences pair: ("hospital beneficência portuguesa de são paulo", "hospital beneficencia portuguesa")
# positive sentences pair: ("hospital beneficência portuguesa de são paulo", "terapia hospital del corazon")
# ================================================================================
# positive pair: (E_b1dcef5248f060, E_66b81caa4a5e9c)
# negative pair: (E_b1dcef5248f060, E_18fd95c4441191)
# positive sentences pair: ("حلويات الذواق", "le gourmet | الذواق")
# positive sentences pair: ("حلويات الذواق", "الاستراحه القويه 🎶")
# ================================================================================
# positive pair: (E_c12bcbe809dd4e, E_7e57ed224258b1)
# negative pair: (E_c12bcbe809dd4e, E_100f6420c0615c)
# positive sentences pair: ("varasy", "versai cafe | فرساي كافيه")
# positive sentences pair: ("varasy", "national oil varco co.")
# ================================================================================
# positive pair: (E_58d16e5dc71b0f, E_b6af1af913a696)
# negative pair: (E_58d16e5dc71b0f, E_399f53aa196446)
# positive sentences pair: ("oldenburger schloss", "schloß")
# positive sentences pair: ("oldenburger schloss", "schleuse gambsheim")
# ================================================================================
# positive pair: (E_03ea6481f26d67, E_1ecfb302bf8f6b)
# negative pair: (E_03ea6481f26d67, E_8a854081ca77bc)
# positive sentences pair: ("trümmerberg im volkspark friedrichshain", "großer bunkerberg")
# positive sentences pair: ("trümmerberg im volkspark friedrichshain", "tropfsteinhöhlen")
# ================================================================================
# positive pair: (E_508a048aae8487, E_539ed9ced29aa8)
# ...
# positive sentences pair: ("tigertopoki", "buddy's pancit lucban")
# ================================================================================
# positive pair: (E_7d03d8cdf5ff5b, E_9f195a31302626)
# negative pair: (E_7d03d8cdf5ff5b, E_96faf80683af71)
# positive sentences pair: ("fire & life safety america - sanford", "fire and life safety america")
# positive sentences pair: ("fire & life safety america - sanford", "reedy creek fire station 2")
# ================================================================================
# positive pair: (E_4fe1bba49b02ec, E_92671d624bc56c)
# negative pair: (E_4fe1bba49b02ec, E_e7880174821642)
# positive sentences pair: ("poolside bingo @ orange lake resort (west village)", "holiday inn club vacations orlando - orange lake resort")
# positive sentences pair: ("poolside bingo @ orange lake resort (west village)", "fantasy world ii vacation villas pool")
# ================================================================================
# positive pair: (E_1a465bc225fdc3, E_be1c63e4ab8112)
# negative pair: (E_1a465bc225fdc3, E_a31f749072c96f)
# positive sentences pair: ("cia do ar escola de aviação", "escola de aviação civil- cia do ar")
# positive sentences pair: ("cia do ar escola de aviação", "porto seguro cia seguros gerais")
# ================================================================================
# positive pair: (E_b204cd62c20a1d, E_8ffdb98a9d3646)
# negative pair: (E_b204cd62c20a1d, E_ab58142ce54e3b)
# positive sentences pair: ("atm bank bukopin", "ruang rapat bank bukopin kcu manado")
# positive sentences pair: ("atm bank bukopin", "united coconut planters bank")
# ================================================================================
# positive pair: (E_20f880117a6b58, E_02c451ec061e9b)
# negative pair: (E_20f880117a6b58, E_e00aaea9a9301d)
# positive sentences pair: ("銘傳大學m302", "銘傳大學s208")
# positive sentences pair: ("銘傳大學m302", "靜宜大學希嘉苑")
# ================================================================================
# positive pair: (E_1abfec750e9cad, E_0e36f4b87d1b39)
# negative pair: (E_1abfec750e9cad, E_3459a38c76a74a)
# positive sentences pair: ("中華電信 芝山服務中心", "chunghwa telecom")
# positive sentences pair: ("中華電信 芝山服務中心", "神腦國際信義客服中心")
# ================================================================================
# positive pair: (E_97c0a8b4eef258, E_0c376c16ed658b)
# negative pair: (E_97c0a8b4eef258, E_ac2e09545b1bc5)
# positive sentences pair: ("watson's pub", "watson's house of ale's")
# positive sentences pair: ("watson's pub", "urban pub")
# ================================================================================
# positive pair: (E_57bb93f3befb0c, E_d88b2cd47e537c)
# negative pair: (E_57bb93f3befb0c, E_28dbecf03a948c)
# positive sentences pair: ("然別湖", "shikaribetsu lake")
# positive sentences pair: ("然別湖", "極楽屋")
# ================================================================================
# positive pair: (E_aea1f8964ac08d, E_22855df9de9d2c)
# negative pair: (E_aea1f8964ac08d, E_d6eb3df30a6cb4)
# positive sentences pair: ("piazza dei rucellai", "piazza rucellai")
# positive sentences pair: ("piazza dei rucellai", "piazza aligheri")
# ================================================================================
# positive pair: (E_4a471624f37098, E_254282b6a49ead)
# negative pair: (E_4a471624f37098, E_f50dcb57eb3e9a)
# positive sentences pair: ("rīgas iela11a", "tc valdeka")
# positive sentences pair: ("rīgas iela11a", "rīgas 14. vakara (mainu) vidusskola")
# ================================================================================
# positive pair: (E_bc527949fd6fbd, E_28d7b228b8eea6)
# negative pair: (E_bc527949fd6fbd, E_c684dbedc094f2)
# positive sentences pair: ("finch east dental care", "finch east dental clinic")
# positive sentences pair: ("finch east dental care", "star smile dental center")
# ================================================================================
# positive pair: (E_e39722fa714f14, E_c03f09ea854d66)
# negative pair: (E_e39722fa714f14, E_f6c8ed783a5949)
# positive sentences pair: ("smokey point motor inn", "smokey point motel")
# positive sentences pair: ("smokey point motor inn", "rustic inn at jackson hole")
# ================================================================================
# positive pair: (E_e845ee2baad361, E_1f0fde3504397d)
# negative pair: (E_e845ee2baad361, E_65d478e09437da)
# positive sentences pair: ("koulun aula", "luokka ai4")
# positive sentences pair: ("koulun aula", "pikkolan koulu")
# ================================================================================
# positive pair: (E_71de6c0c29da56, E_3c35a5420f1075)
# negative pair: (E_71de6c0c29da56, E_a6e129999d95e1)
# positive sentences pair: ("woki organic market - gracia", "woki organic market")
# positive sentences pair: ("woki organic market - gracia", "farmacia reis")
# ================================================================================
# positive pair: (E_47ae8ed850661a, E_094df5f4bb1846)
# negative pair: (E_47ae8ed850661a, E_f7f71c0dc1cae4)
# positive sentences pair: ("empark aparcamiento de colón", "empark aparcamiento plaza de colón")
# positive sentences pair: ("empark aparcamiento de colón", "opticien générale d'optique evreux")
# ================================================================================
# positive pair: (E_a89afaecee84d4, E_fb429e771d4755)
# negative pair: (E_a89afaecee84d4, E_a1745c9691b5c7)
# positive sentences pair: ("truevine baptist church", "true vine church")
# positive sentences pair: ("truevine baptist church", "evangelistic ministries church")
# ================================================================================
# positive pair: (E_32caf1f2f1b392, E_a33c2e68bf15d7)
# negative pair: (E_32caf1f2f1b392, E_e43b07d18703f7)
# positive sentences pair: ("merrill lynch wealth management advisor scott l johnson", "merrill lynch wealth management advisor tucker a johnson")
# positive sentences pair: ("merrill lynch wealth management advisor scott l johnson", "nationwide insurance - douglas baird morgan")
# ================================================================================
# positive pair: (E_b648c8ad149a49, E_b5f34dcd57c17e)
# negative pair: (E_b648c8ad149a49, E_3f9478ad09c2ef)
# positive sentences pair: ("зал 2 групповая", "сауна физкульта)")
# positive sentences pair: ("зал 2 групповая", "зеркало в тупзике")
# ================================================================================
# positive pair: (E_a1f8e697c1fb94, E_e487a8294fd1ba)
# negative pair: (E_a1f8e697c1fb94, E_150407b57506e1)
# positive sentences pair: ("naif", "naif chicken al qadsiya")
# positive sentences pair: ("naif", "tv gaba")
# ================================================================================
# positive pair: (E_c2b5b8e31ce825, E_4e713c116052c7)
# negative pair: (E_c2b5b8e31ce825, E_da1d4b02ac8aa7)
# positive sentences pair: ("cesvi auto sucursal martelli", "automotores collins")
# positive sentences pair: ("cesvi auto sucursal martelli", "empório 38")
# ================================================================================
# positive pair: (E_dfe303eef60b41, E_3fd47e3bc9f7a4)
# negative pair: (E_dfe303eef60b41, E_b444f72c68010d)
# positive sentences pair: ("join buy zhongan top grade shopping street", "九百中安名品长廊")
# positive sentences pair: ("join buy zhongan top grade shopping street", "东方商厦 | oriental department store")
# ================================================================================
# positive pair: (E_9f49930dc14e25, E_1c60d16afd225f)
# negative pair: (E_9f49930dc14e25, E_13570a90e4afa0)
# positive sentences pair: ("matahari departement store ip", "matahari department store international plaza palembang")
# positive sentences pair: ("matahari departement store ip", "koridor ips sman 68 jakarta")
# ================================================================================
# positive pair: (E_5773607d492b4a, E_6fd7d5dcaa40bb)
# negative pair: (E_5773607d492b4a, E_27dcbc6687b428)
# positive sentences pair: ("christiansen glass & paint", "christiansons glass")
# positive sentences pair: ("christiansen glass & paint", "english clay's room")
# ================================================================================
# positive pair: (E_9a56eed015c90f, E_c20fb183982b6d)
# negative pair: (E_9a56eed015c90f, E_aff02e96ffb30a)
# positive sentences pair: ("единый расчетно-кассовый центр (отделение «первомайское»)", "единый расчетно-кассовый центр, калининский район")
# positive sentences pair: ("единый расчетно-кассовый центр (отделение «первомайское»)", "саратовский йога-центр")
# ================================================================================
# positive pair: (E_ca2666a9a612c2, E_75fe092c43db29)
# negative pair: (E_ca2666a9a612c2, E_b71e308cc9a6b3)
# positive sentences pair: ("manabilang st, marawi city", "amai manabilang street, marawi city")
# positive sentences pair: ("manabilang st, marawi city", "manado trade center")
# ================================================================================
# positive pair: (E_a34804e252214c, E_399762a9e21bc7)
# negative pair: (E_a34804e252214c, E_fa571a7cdcff6c)
# positive sentences pair: ("armazém guimarães riomar", "armazém guimarães")
# positive sentences pair: ("armazém guimarães riomar", "feijoada do carioca")
# ================================================================================
# positive pair: (E_43acc7a3d4a9f0, E_525bb750e75e2d)
# negative pair: (E_43acc7a3d4a9f0, E_3b310ee497ba4e)
# positive sentences pair: ("n-style", "n style mall of emirates")
# positive sentences pair: ("n-style", "shar3")
# ================================================================================
# positive pair: (E_cdbfae11b20f19, E_de44b60725f3cc)
# negative pair: (E_cdbfae11b20f19, E_735dcf083e4ac4)
# positive sentences pair: ("ไอดิน บูติก รีสอร์ท", "puvara tour elephant camp")
# positive sentences pair: ("ไอดิน บูติก รีสอร์ท", "โกเบสเต๊คเฮ้าส์ สยามกิตต์")
# ================================================================================
# positive pair: (E_b8d24af7d3eeda, E_c630e968cd7499)
# negative pair: (E_b8d24af7d3eeda, E_ffd0c1d644c091)
# positive sentences pair: ("ets lemaitre - point fort fichet", "etablissement lemaitre")
# positive sentences pair: ("ets lemaitre - point fort fichet", "apotheek van der elst f.")
# ================================================================================
# positive pair: (E_0e0ae26bc4d8a0, E_fb5b09aab2d471)
# negative pair: (E_0e0ae26bc4d8a0, E_a0636f3d647d05)
# positive sentences pair: ("ска бассейн", ""ска бассейн \"лягушонок\""")
# positive sentences pair: ("ска бассейн", "бунинская штрассе")
# ================================================================================
# positive pair: (E_d4ec72c915cdb9, E_fdc883eeb70a64)
# negative pair: (E_d4ec72c915cdb9, E_0bad5d443f5d50)
# positive sentences pair: ("cici's cafe los angeles, ca", "cici's cafe")
# positive sentences pair: ("cici's cafe los angeles, ca", "ciros pizzeria & beerhouse")
# ================================================================================
# positive pair: (E_ae2594ddfc729c, E_e07ecf5f5775ab)
# negative pair: (E_ae2594ddfc729c, E_9697d787292e86)
# positive sentences pair: ("dreads poa anita", "studio dreads roots")
# positive sentences pair: ("dreads poa anita", "lilian'hair")
# ================================================================================
# positive pair: (E_8b0c79c0056953, E_21f66846a2ae29)
# negative pair: (E_8b0c79c0056953, E_ef66f3e112e3d5)
# positive sentences pair: ("villas de boqueron, compañia de parques nacionales", "villas boqueron")
# positive sentences pair: ("villas de boqueron, compañia de parques nacionales", "boca catalina")
# ================================================================================
# positive pair: (E_8bbeba0b77f71c, E_f4880bbbca90ee)
# negative pair: (E_8bbeba0b77f71c, E_91ffe919c25cca)
# positive sentences pair: ("kantor walikota palangka raya (city hall)", "kantor walikota palangka raya")
# positive sentences pair: ("kantor walikota palangka raya (city hall)", "aula mapalus kantor gubernur")
# ================================================================================
# positive pair: (E_8e40b22aaa2713, E_d7e3d0e89b8495)
# negative pair: (E_8e40b22aaa2713, E_a8f6bb8ec56530)
# positive sentences pair: ("ponta da espera", "terminal da ponta da espera")
# positive sentences pair: ("ponta da espera", "capela n. sra. conceição do outeiro da prainha")
# ================================================================================
# positive pair: (E_d617f3f52e120d, E_b718ae4d2c612c)
# negative pair: (E_d617f3f52e120d, E_5a3a6e0e8777d5)
# positive sentences pair: ("аазс №3 терминал", "чкаловская лестница")
# positive sentences pair: ("аазс №3 терминал", "автосервиз")
# ================================================================================
# positive pair: (E_4f7360b7bbe821, E_1b2360c114c699)
# negative pair: (E_4f7360b7bbe821, E_700ff20b285947)
# positive sentences pair: ("любимая информатика", "алгебра с дириком")
# positive sentences pair: ("любимая информатика", "тэи сфу | торгово-экономический институт сфу")
# ================================================================================
# positive pair: (E_18dd32bbf02ee2, E_c0b1f01d6a1685)
# negative pair: (E_18dd32bbf02ee2, E_1cc6f043b02ec1)
# positive sentences pair: ("edificio loma linda", "lomalinda")
# positive sentences pair: ("edificio loma linda", "iglesia san marcos")
# ================================================================================
# positive pair: (E_f8d2af8fe8623b, E_0ea9a87fe59713)
# negative pair: (E_f8d2af8fe8623b, E_fb52be71dbdefa)
# positive sentences pair: ("魚彩工房 一鮮満 おもろまち店", "issenman")
# positive sentences pair: ("魚彩工房 一鮮満 おもろまち店", "ガスト那覇おもろまち店")
# ================================================================================
# positive pair: (E_82f752e367fb11, E_7f6e0caa0dcb9f)
# negative pair: (E_82f752e367fb11, E_cec3fcb57ccae4)
# positive sentences pair: ("s.v chat bhandar", "s.v chat bandhar")
# positive sentences pair: ("s.v chat bhandar", "vada kadai")
# ================================================================================
# positive pair: (E_b281df5fc162de, E_91a4be4f84ad2e)
# negative pair: (E_b281df5fc162de, E_515a4b9b9d48e9)
# positive sentences pair: ("athob cafe", "athob | كوفي عذوب")
# positive sentences pair: ("athob cafe", "dose cafe")
# ================================================================================
# positive pair: (E_9b51437bdafd22, E_7d64f6122f10d5)
# negative pair: (E_9b51437bdafd22, E_1a5a999f34d776)
# positive sentences pair: ("piscina polideportivo rufino bernedo", "polideportivo rufino bernedo")
# positive sentences pair: ("piscina polideportivo rufino bernedo", "hernando de magallanes")
# ================================================================================
# positive pair: (E_c49695aa402849, E_323a473f6bad7e)
# negative pair: (E_c49695aa402849, E_bb8cdcb8309fdf)
# positive sentences pair: ("галерея стиля inmode", "inmode")
# positive sentences pair: ("галерея стиля inmode", "театр-студия александра гончарука")
# ================================================================================
# positive pair: (E_bdcce41b53b25f, E_a05f47ce14bc36)
# negative pair: (E_bdcce41b53b25f, E_6ba87820813bc2)
# positive sentences pair: ("casa nostra bar", "casa woodstock, casa nostra bar")
# positive sentences pair: ("casa nostra bar", "café tango @afdaks")
# ================================================================================
# positive pair: (E_8dc2ee2f0d1de5, E_856925a42a8e90)
# negative pair: (E_8dc2ee2f0d1de5, E_c944854fc3f217)
# positive sentences pair: ("parroquia nuestra señora de fatima (juana koslay)", "parroquia nuestra señora del rosario de fátima")
# positive sentences pair: ("parroquia nuestra señora de fatima (juana koslay)", "santuario de la inmaculada concepción")
# ================================================================================
# positive pair: (E_9bdc6cb82c7449, E_0fadbe333657bf)
# negative pair: (E_9bdc6cb82c7449, E_a48b03a019f808)
# positive sentences pair: ("школа 10, кабинет 304. биология- химия", "школа 10, правый угол")
# positive sentences pair: ("школа 10, кабинет 304. биология- химия", "школа №45")

# %%
len(results_test_df), results_test_df.value_counts("matched") / len(results_test_df)
# Out:
# (1344027, matched
#  0    0.856847
#  1    0.143153
#  dtype: float64)

# %% [markdown]
# # Make Ditto's input

# %%
def make_ditto_output(result_df, train_df, output_path="example.tsv"):
    result_df = result_df.copy()

    feature_cols = [*CFG.TEXT_COLS, *CFG.NUM_COLS]
    result_df = result_df.merge(
        train_df[["id"] + feature_cols].rename({"id": "id1", **{col: f"{col}1" for col in feature_cols}}, axis=1), on="id1"
    ).merge(
        train_df[["id"] + feature_cols].rename({"id": "id2", **{col: f"{col}2" for col in feature_cols}}, axis=1), on="id2"
    )

    tqdm.pandas(desc="Create ditto label")
    result_df.progress_apply(
        lambda x: (
            " ".join([f"COL {col} VAL {x[col + '1']}" for col in CFG.TEXT_COLS] + [f"COL {col} VAL {x[col + '1']:.3f}" for col in CFG.NUM_COLS]),
            " ".join([f"COL {col} VAL {x[col + '2']}" for col in CFG.TEXT_COLS] + [f"COL {col} VAL {x[col + '2']:.3f}" for col in CFG.NUM_COLS]),
            x['matched']
        ), axis='columns', result_type='expand'
    ).to_csv(f"{output_path}.gz", index=False, header=False, sep="\t", compression="gzip")

# %%
make_ditto_output(results_dev_df, train_dev, output_path=f"ditto_dev_n{CFG.N_CLOSEST}_seed{CFG.RANDOM_SEED}.tsv")
# Out:
# creating ditto labels...:   0%|          | 0/1346336 [00:00<?, ?it/s]

# %%
make_ditto_output(results_test_df, train_test, output_path=f"ditto_test_n{CFG.N_CLOSEST}_seed{CFG.RANDOM_SEED}.tsv")
# Out:
# creating ditto labels...:   0%|          | 0/1344027 [00:00<?, ?it/s]

# %%
ditto_dev_df = pd.read_csv(f"ditto_dev_n{CFG.N_CLOSEST}_seed{CFG.RANDOM_SEED}.tsv.gz", names=["left", "rihgt", "matched"], sep="\t", compression="gzip")

# %%
ditto_test_df = pd.read_csv(f"ditto_test_n{CFG.N_CLOSEST}_seed{CFG.RANDOM_SEED}.tsv.gz", names=["left", "rihgt", "matched"], sep="\t", compression="gzip")

# %%
ditto_dev_df.value_counts("matched") / len(ditto_dev_df)
# Out:
# matched
# 0    0.856983
# 1    0.143017
# dtype: float64

# %%
ditto_test_df.value_counts("matched") / len(ditto_test_df)
# Out:
# matched
# 0    0.856847
# 1    0.143153
# dtype: float64

# %%
ditto_dev_df
# Out:
#                                                                                                                                                                                                                                                                                                                 left  \
# 0        COL name VAL krystal height COL address VAL lintang delima 14 COL city VAL island glades COL state VAL penang COL zip VAL 11700 COL country VAL my COL url VAL - COL phone VAL - COL categories VAL residential buildings (apartments / condos), buildings COL latitude VAL 5.384 COL longitude VAL 100.299
# 1                                                                                         COL name VAL top bowl, skudai parade COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 1.538 COL longitude VAL 103.674
# 2                                                                                                  COL name VAL cinenye garden COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL sg COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 1.341 COL longitude VAL 103.734
# 3                                                                               COL name VAL luna's first home@compass heights COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL sg COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 1.391 COL longitude VAL 103.896
# 4                                                                    COL name VAL esplanade by the bay COL address VAL esplanade COL city VAL singapore COL state VAL singapore COL zip VAL - COL country VAL sg COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 1.290 COL longitude VAL 103.856
# ...                                                                                                                                                                                                                                                                                                              ...
# 1346331                                                              COL name VAL pullman grand hotel gym COL address VAL - COL city VAL kinşasa COL state VAL kinshasa city COL zip VAL - COL country VAL cd COL url VAL - COL phone VAL - COL categories VAL gyms COL latitude VAL -4.313 COL longitude VAL 15.273
# 1346332                                                                              COL name VAL portobello COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL sc COL url VAL - COL phone VAL - COL categories VAL italian restaurants COL latitude VAL -4.478 COL longitude VAL 55.247
# 1346333                                                                   COL name VAL portobello restaraunt COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL sc COL url VAL - COL phone VAL - COL categories VAL italian restaurants COL latitude VAL -4.478 COL longitude VAL 55.247
# 1346334                                                                                           COL name VAL aguascalientes COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL xx COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL -4.215 COL longitude VAL -94.219
# 1346335                                                                                              COL name VAL bloemfontein COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL eg COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 29.080 COL longitude VAL 26.178
#
#                                                                                                                                                                                                                                                        rihgt  \
# 0                           COL name VAL island glades-krystal heights COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 5.384 COL longitude VAL 100.298
# 1                           COL name VAL island glades-krystal heights COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 5.384 COL longitude VAL 100.298
# 2                           COL name VAL island glades-krystal heights COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 5.384 COL longitude VAL 100.298
# 3                           COL name VAL island glades-krystal heights COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 5.384 COL longitude VAL 100.298
# 4                           COL name VAL island glades-krystal heights COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 5.384 COL longitude VAL 100.298
# ...                                                                                                                                                                                                                                                      ...
# 1346331               COL name VAL pullmam gym COL address VAL - COL city VAL kinşasa COL state VAL kinshasa COL zip VAL - COL country VAL cd COL url VAL - COL phone VAL - COL categories VAL college gyms COL latitude VAL -4.312 COL longitude VAL 15.273
# 1346332           COL name VAL portobello restaraunt COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL sc COL url VAL - COL phone VAL - COL categories VAL italian restaurants COL latitude VAL -4.478 COL longitude VAL 55.247
# 1346333                      COL name VAL portobello COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL sc COL url VAL - COL phone VAL - COL categories VAL italian restaurants COL latitude VAL -4.478 COL longitude VAL 55.247
# 1346334                                        COL name VAL guayaquil COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL xx COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL -3.693 COL longitude VAL -95.757
# 1346335  COL name VAL die boer theatre/restaurant COL address VAL durbanville COL city VAL - COL state VAL - COL zip VAL - COL country VAL xx COL url VAL - COL phone VAL - COL categories VAL music venues COL latitude VAL 33.857 COL longitude VAL 18.761
#
#          matched
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1346331        1
# 1346332        1
# 1346333        1
# 1346334        1
# 1346335        1
#
# [1346336 rows x 3 columns]

# %%
ditto_test_df
# Out:
#                                                                                                                                                                                                                                                                                                       left  \
# 0                 COL name VAL proton bunga raya parts service center COL address VAL - COL city VAL melaka COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL professional & other places, auto workshops COL latitude VAL 2.233 COL longitude VAL 102.233
# 1                                                  COL name VAL yueka one-stop auto service COL address VAL #166 COL city VAL phnom penh COL state VAL 金边 COL zip VAL - COL country VAL kh COL url VAL - COL phone VAL - COL categories VAL auto garages COL latitude VAL 11.612 COL longitude VAL 104.928
# 2                 COL name VAL proton bunga raya parts service center COL address VAL - COL city VAL melaka COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL professional & other places, auto workshops COL latitude VAL 2.233 COL longitude VAL 102.233
# 3        COL name VAL sin siang hin (m) proton service centre COL address VAL jalan gombak COL city VAL kuala lumpur COL state VAL wp kuala lumpur COL zip VAL 53300 COL country VAL my COL url VAL - COL phone VAL - COL categories VAL automotive shops COL latitude VAL 3.217 COL longitude VAL 101.746
# 4                 COL name VAL proton bunga raya parts service center COL address VAL - COL city VAL melaka COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL professional & other places, auto workshops COL latitude VAL 2.233 COL longitude VAL 102.233
# ...                                                                                                                                                                                                                                                                                                    ...
# 1344022                                                     COL name VAL petit anse COL address VAL chemin anse soleil COL city VAL - COL state VAL baie lazare COL zip VAL - COL country VAL sc COL url VAL - COL phone VAL - COL categories VAL beaches COL latitude VAL -4.755 COL longitude VAL 55.467
# 1344023      COL name VAL petite anse COL address VAL chemin anse soleil COL city VAL mahé COL state VAL baie lazare COL zip VAL - COL country VAL sc COL url VAL http://www.fourseasons.com/seychelles/ COL phone VAL 4393000 COL categories VAL beaches COL latitude VAL -4.755 COL longitude VAL 55.465
# 1344024                                                        COL name VAL broome district hospital COL address VAL - COL city VAL broome COL state VAL wa COL zip VAL - COL country VAL au COL url VAL - COL phone VAL - COL categories VAL hospitals COL latitude VAL -17.960 COL longitude VAL 122.237
# 1344025                    COL name VAL familiprix extra - johanne giguère COL address VAL 710 montée paiement COL city VAL gatineau COL state VAL qc COL zip VAL j8r 4a3 COL country VAL ca COL url VAL - COL phone VAL - COL categories VAL pharmacies COL latitude VAL 59.029 COL longitude VAL -97.765
# 1344026                                                                             COL name VAL lake tanganyika COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL bi COL url VAL - COL phone VAL - COL categories VAL lakes COL latitude VAL -3.869 COL longitude VAL 29.379
#
#                                                                                                                                                                                                                                                                                                  rihgt  \
# 0                                                COL name VAL bunga raya part @ service sdn. bhd. COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL automotive shops COL latitude VAL 2.234 COL longitude VAL 102.233
# 1                                                COL name VAL bunga raya part @ service sdn. bhd. COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL my COL url VAL - COL phone VAL - COL categories VAL automotive shops COL latitude VAL 2.234 COL longitude VAL 102.233
# 2                             COL name VAL sin siang hin proton service dealer COL address VAL jalan gombak COL city VAL 吉隆坡 COL state VAL 吉隆坡 COL zip VAL 53000 COL country VAL my COL url VAL - COL phone VAL - COL categories VAL automotive shops COL latitude VAL 3.196 COL longitude VAL 101.704
# 3                             COL name VAL sin siang hin proton service dealer COL address VAL jalan gombak COL city VAL 吉隆坡 COL state VAL 吉隆坡 COL zip VAL 53000 COL country VAL my COL url VAL - COL phone VAL - COL categories VAL automotive shops COL latitude VAL 3.196 COL longitude VAL 101.704
# 4                   COL name VAL proton edar kepong branch COL address VAL jalan 3/34a COL city VAL kuala lumpur COL state VAL federal territory of kuala lum COL zip VAL 52100 COL country VAL my COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL 3.213 COL longitude VAL 101.646
# ...                                                                                                                                                                                                                                                                                                ...
# 1344022  COL name VAL petite anse COL address VAL chemin anse soleil COL city VAL mahé COL state VAL baie lazare COL zip VAL - COL country VAL sc COL url VAL http://www.fourseasons.com/seychelles/ COL phone VAL 4393000 COL categories VAL beaches COL latitude VAL -4.755 COL longitude VAL 55.465
# 1344023                                                 COL name VAL petit anse COL address VAL chemin anse soleil COL city VAL - COL state VAL baie lazare COL zip VAL - COL country VAL sc COL url VAL - COL phone VAL - COL categories VAL beaches COL latitude VAL -4.755 COL longitude VAL 55.467
# 1344024                                              COL name VAL broome hospital COL address VAL - COL city VAL broome COL state VAL western australia COL zip VAL - COL country VAL au COL url VAL - COL phone VAL - COL categories VAL hospitals COL latitude VAL -17.961 COL longitude VAL 122.237
# 1344025          COL name VAL familiprix - johanne giguère COL address VAL 710, montée paiement COL city VAL gatineau COL state VAL qc COL zip VAL j8r 4a3 COL country VAL ca COL url VAL - COL phone VAL +18196691734 COL categories VAL pharmacies COL latitude VAL 45.503 COL longitude VAL -75.677
# 1344026                                                                COL name VAL lever de soleil - tanganyika COL address VAL - COL city VAL - COL state VAL - COL zip VAL - COL country VAL bi COL url VAL - COL phone VAL - COL categories VAL - COL latitude VAL -3.379 COL longitude VAL 29.347
#
#          matched
# 0              1
# 1              0
# 2              0
# 3              1
# 4              0
# ...          ...
# 1344022        1
# 1344023        1
# 1344024        1
# 1344025        1
# 1344026        1
#
# [1344027 rows x 3 columns]

# %% [markdown]
# # Make datasets of various size

# %%
import os


def make_various_sized_datasets(ditto_df, file_prefix):
    n_full_length = len(ditto_df)
    sizes = {
        "full": n_full_length,
        "xlarge": n_full_length // 4,
        "large": n_full_length // 16,
        "medium": n_full_length // 64,
        "small": n_full_length // 256,
    }
    for size, length in tqdm(sizes.items()):
        df = ditto_df.sample(length, random_state=CFG.RANDOM_SEED)
        out_filepath = f"{file_prefix}_{size}.tsv"
        df.to_csv(f"{out_filepath}.gz", index=False, header=False, sep="\t", compression="gzip")

    return sizes

# %%
make_various_sized_datasets(ditto_dev_df, f"ditto_dev_feat_all_n{CFG.N_CLOSEST}_seed{CFG.RANDOM_SEED}")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# cp: cannot stat '{out_filepath}.gz': No such file or directory
# cp: cannot stat '{out_filepath}.gz': No such file or directory
# cp: cannot stat '{out_filepath}.gz': No such file or directory
# cp: cannot stat '{out_filepath}.gz': No such file or directory
# cp: cannot stat '{out_filepath}.gz': No such file or directory
# {'full': 1346336,
#  'large': 84146,
#  'medium': 21036,
#  'small': 5259,
#  'xlarge': 336584}

# %%
make_various_sized_datasets(ditto_test_df, f"ditto_test_feat_all_n{CFG.N_CLOSEST}_seed{CFG.RANDOM_SEED}")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# {'full': 1344027,
#  'large': 84001,
#  'medium': 21000,
#  'small': 5250,
#  'xlarge': 336006}

# %%
! cp ditto_*.tsv.gz "{DATA}"/.
